# %%
import pandas  as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

import nltk
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing import sequence #unique words

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,SimpleRNN, Dropout, Embedding
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
df=pd.read_table('/content/amazon_alexa.tsv')

# %%
df.head()
# Out:
#    rating       date         variation  \
# 0       5  31-Jul-18  Charcoal Fabric
# 1       5  31-Jul-18  Charcoal Fabric
# 2       4  31-Jul-18    Walnut Finish
# 3       5  31-Jul-18  Charcoal Fabric
# 4       5  31-Jul-18  Charcoal Fabric
#
#                                     verified_reviews  feedback
# 0                                      Love my Echo!         1
# 1                                          Loved it!         1
# 2  Sometimes while playing a game, you can answer...         1
# 3  I have had a lot of fun with this thing. My 4 ...         1
# 4                                              Music         1

# %%
df.drop(['date','variation'],inplace=True,axis=1)

# %%
df
# Out:
#       rating                                   verified_reviews  feedback
# 0          5                                      Love my Echo!         1
# 1          5                                          Loved it!         1
# 2          4  Sometimes while playing a game, you can answer...         1
# 3          5  I have had a lot of fun with this thing. My 4 ...         1
# 4          5                                              Music         1
# ...      ...                                                ...       ...
# 3145       5  Perfect for kids, adults and everyone in betwe...         1
# 3146       5  Listening to music, searching locations, check...         1
# 3147       5  I do love these things, i have them running my...         1
# 3148       5  Only complaint I have is that the sound qualit...         1
# 3149       4                                               Good         1
#
# [3150 rows x 3 columns]

# %%
df['feedback'].value_counts()
# Out:
# 1    2893
# 0     257
# Name: feedback, dtype: int64

# %%
def cleantext(text):
  tokens = word_tokenize(text.lower())
  ftoken = [t for t in tokens if(t.isalpha())]

  stop = stopwords.words("english")
  ctoken = [t for t in ftoken if(t not in stop)]

  lemma = WordNetLemmatizer()
  ltoken = [lemma.lemmatize(t) for t in ctoken]

  return " ".join(ltoken)

# %%
df["clean_review"]=df["verified_reviews"].apply(cleantext)

# %%
df.head()
# Out:
#    rating                                   verified_reviews  feedback  \
# 0       5                                      Love my Echo!         1
# 1       5                                          Loved it!         1
# 2       4  Sometimes while playing a game, you can answer...         1
# 3       5  I have had a lot of fun with this thing. My 4 ...         1
# 4       5                                              Music         1
#
#                                         clean_review
# 0                                          love echo
# 1                                              loved
# 2  sometimes playing game answer question correct...
# 3  lot fun thing yr old learns dinosaur control l...
# 4                                              music

# %%
x = df["clean_review"]
y = df["feedback"]

# %%
x
# Out:
# 0                                               love echo
# 1                                                   loved
# 2       sometimes playing game answer question correct...
# 3       lot fun thing yr old learns dinosaur control l...
# 4                                                   music
#                               ...
# 3145                           perfect kid adult everyone
# 3146    listening music searching location checking ti...
# 3147    love thing running entire home tv light thermo...
# 3148    complaint sound quality great mostly use comma...
# 3149                                                 good
# Name: clean_review, Length: 3150, dtype: object

# %%
y
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 3145    1
# 3146    1
# 3147    1
# 3148    1
# 3149    1
# Name: feedback, Length: 3150, dtype: int64

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.3, random_state=1)

# %%
sentlen = []

for sent in df["clean_review"]:
  sentlen.append(len(word_tokenize(sent)))

df["SentLen"] = sentlen
df.head()
# Out:
#    rating                                   verified_reviews  feedback  \
# 0       5                                      Love my Echo!         1
# 1       5                                          Loved it!         1
# 2       4  Sometimes while playing a game, you can answer...         1
# 3       5  I have had a lot of fun with this thing. My 4 ...         1
# 4       5                                              Music         1
#
#                                         clean_review  SentLen
# 0                                          love echo        2
# 1                                              loved        1
# 2  sometimes playing game answer question correct...       17
# 3  lot fun thing yr old learns dinosaur control l...       18
# 4                                              music        1

# %%
max(sentlen)
# Out:
# 245

# %%
max_len = np.quantile(sentlen, 0.95)
max_len
# Out:
# 40.0

# %%
tok = Tokenizer(char_level=False, split=" ")


tok.fit_on_texts(xtrain)
tok.index_word
# Out:
# {1: 'love',
#  2: 'echo',
#  3: 'great',
#  4: 'alexa',
#  5: 'work',
#  6: 'music',
#  7: 'use',
#  8: 'like',
#  9: 'sound',
#  10: 'device',
#  11: 'easy',
#  12: 'one',
#  13: 'dot',
#  14: 'set',
#  15: 'speaker',
#  16: 'good',
#  17: 'product',
#  18: 'thing',
#  19: 'get',
#  20: 'amazon',
#  21: 'time',
#  22: 'play',
#  23: 'home',
#  24: 'still',
#  25: 'would',
#  26: 'really',
#  27: 'light',
#  28: 'prime',
#  29: 'day',
#  30: 'smart',
#  31: 'also',
#  32: 'show',
#  33: 'much',
#  34: 'new',
#  35: 'better',
#  36: 'quality',
#  37: 'well',
#  38: 'bought',
#  39: 'room',
#  40: 'fun',
#  41: 'far',
#  42: 'need',
#  43: 'alarm',
#  44: 'got',
#  45: 'even',
#  46: 'could',
#  47: 'everything',
#  48: 'plus',
#  49: 'feature',
#  50: 'make',
#  51: 'able',
#  52: 'video',
#  53: 'learning',
#  54: 'say',
#  55: 'turn',
#  56: 'house',
#  57: 'clock',
#  58: 'nice',
#  59: 'weather',
#  60: 'buy',
#  61: 'phone',
#  62: 'want',
#  63: 'ask',
#  64: 'tv',
#  65: 'little',
#  66: 'know',
#  67: 'hub',
#  68: 'tell',
#  69: 'used',
#  70: 'using',
#  71: 'spot',
#  72: 'price',
#  73: 'purchase',
#  74: 'bulb',
#  75: 'see',
#  76: 'screen',
#  77: 'voice',
#  78: 'getting',
#  79: 'command',
#  80: 'without',
#  81: 'perfect',
#  82: 'app',
#  83: 'amazing',
#  84: 'setup',
#  85: 'control',
#  86: 'bedroom',
#  87: 'lot',
#  88: 'listen',
#  89: 'way',
#  90: 'first',
#  91: 'many',
#  92: 'think',
#  93: 'purchased',
#  94: 'connect',
#  95: 'best',
#  96: 'question',
#  97: 'look',
#  98: 'wish',
#  99: 'family',
#  100: 'go',
#  101: 'find',
#  102: 'two',
#  103: 'problem',
#  104: 'song',
#  105: 'ca',
#  106: 'issue',
#  107: 'awesome',
#  108: 'working',
#  109: 'expected',
#  110: 'item',
#  111: 'another',
#  112: 'fine',
#  113: 'kitchen',
#  114: 'going',
#  115: 'pretty',
#  116: 'small',
#  117: 'listening',
#  118: 'playing',
#  119: 'bluetooth',
#  120: 'etc',
#  121: 'call',
#  122: 'hear',
#  123: 'watch',
#  124: 'take',
#  125: 'volume',
#  126: 'list',
#  127: 'though',
#  128: 'every',
#  129: 'gift',
#  130: 'sure',
#  131: 'try',
#  132: 'news',
#  133: 'cool',
#  134: 'happy',
#  135: 'thought',
#  136: 'star',
#  137: 'size',
#  138: 'help',
#  139: 'setting',
#  140: 'skill',
#  141: 'stick',
#  142: 'movie',
#  143: 'refurbished',
#  144: 'connected',
#  145: 'option',
#  146: 'loved',
#  147: 'worked',
#  148: 'definitely',
#  149: 'fire',
#  150: 'unit',
#  151: 'money',
#  152: 'recommend',
#  153: 'right',
#  154: 'timer',
#  155: 'old',
#  156: 'wanted',
#  157: 'plug',
#  158: 'give',
#  159: 'add',
#  160: 'already',
#  161: 'never',
#  162: 'made',
#  163: 'night',
#  164: 'since',
#  165: 'wifi',
#  166: 'keep',
#  167: 'google',
#  168: 'simple',
#  169: 'answer',
#  170: 'different',
#  171: 'learn',
#  172: 'come',
#  173: 'information',
#  174: 'u',
#  175: 'back',
#  176: 'enough',
#  177: 'second',
#  178: 'favorite',
#  179: 'seems',
#  180: 'camera',
#  181: 'part',
#  182: 'enjoy',
#  183: 'kid',
#  184: 'trying',
#  185: 'reason',
#  186: 'original',
#  187: 'absolutely',
#  188: 'enjoying',
#  189: 'radio',
#  190: 'yet',
#  191: 'deal',
#  192: 'something',
#  193: 'fact',
#  194: 'morning',
#  195: 'full',
#  196: 'big',
#  197: 'sometimes',
#  198: 'internet',
#  199: 'worth',
#  200: 'anything',
#  201: 'talking',
#  202: 'year',
#  203: 'life',
#  204: 'week',
#  205: 'around',
#  206: 'system',
#  207: 'disappointed',
#  208: 'program',
#  209: 'wake',
#  210: 'understand',
#  211: 'long',
#  212: 'perfectly',
#  213: 'instruction',
#  214: 'wife',
#  215: 'thank',
#  216: 'living',
#  217: 'came',
#  218: 'excellent',
#  219: 'update',
#  220: 'access',
#  221: 'away',
#  222: 'white',
#  223: 'addition',
#  224: 'built',
#  225: 'generation',
#  226: 'hue',
#  227: 'always',
#  228: 'install',
#  229: 'asking',
#  230: 'month',
#  231: 'read',
#  232: 'forward',
#  233: 'else',
#  234: 'found',
#  235: 'ring',
#  236: 'game',
#  237: 'youtube',
#  238: 'easier',
#  239: 'bit',
#  240: 'capability',
#  241: 'wonderful',
#  242: 'especially',
#  243: 'almost',
#  244: 'friend',
#  245: 'free',
#  246: 'easily',
#  247: 'added',
#  248: 'hour',
#  249: 'however',
#  250: 'user',
#  251: 'daughter',
#  252: 'reminder',
#  253: 'feel',
#  254: 'may',
#  255: 'loud',
#  256: 'clear',
#  257: 'minute',
#  258: 'stuff',
#  259: 'done',
#  260: 'spotify',
#  261: 'firestick',
#  262: 'put',
#  263: 'change',
#  264: 'computer',
#  265: 'multiple',
#  266: 'sleep',
#  267: 'looking',
#  268: 'son',
#  269: 'convenient',
#  270: 'cable',
#  271: 'fast',
#  272: 'order',
#  273: 'must',
#  274: 'nothing',
#  275: 'husband',
#  276: 'whole',
#  277: 'asked',
#  278: 'figure',
#  279: 'lamp',
#  280: 'live',
#  281: 'difference',
#  282: 'actually',
#  283: 'word',
#  284: 'daily',
#  285: 'sale',
#  286: 'link',
#  287: 'quite',
#  288: 'top',
#  289: 'button',
#  290: 'adding',
#  291: 'joke',
#  292: 'start',
#  293: 'couple',
#  294: 'apps',
#  295: 'probably',
#  296: 'people',
#  297: 'said',
#  298: 'started',
#  299: 'ease',
#  300: 'talk',
#  301: 'half',
#  302: 'function',
#  303: 'overall',
#  304: 'us',
#  305: 'tech',
#  306: 'support',
#  307: 'helpful',
#  308: 'useful',
#  309: 'next',
#  310: 'account',
#  311: 'connection',
#  312: 'bad',
#  313: 'station',
#  314: 'ability',
#  315: 'pleased',
#  316: 'audio',
#  317: 'complaint',
#  318: 'watching',
#  319: 'book',
#  320: 'super',
#  321: 'trouble',
#  322: 'buying',
#  323: 'le',
#  324: 'number',
#  325: 'wo',
#  326: 'brand',
#  327: 'plugged',
#  328: 'touch',
#  329: 'excited',
#  330: 'name',
#  331: 'playlist',
#  332: 'request',
#  333: 'tried',
#  334: 'ever',
#  335: 'review',
#  336: 'display',
#  337: 'needed',
#  338: 'response',
#  339: 'gave',
#  340: 'pandora',
#  341: 'gen',
#  342: 'assistant',
#  343: 'recipe',
#  344: 'shopping',
#  345: 'office',
#  346: 'soon',
#  347: 'highly',
#  348: 'philip',
#  349: 'technology',
#  350: 'service',
#  351: 'package',
#  352: 'stand',
#  353: 'satisfied',
#  354: 'respond',
#  355: 'took',
#  356: 'several',
#  357: 'paid',
#  358: 'experience',
#  359: 'pay',
#  360: 'available',
#  361: 'chat',
#  362: 'value',
#  363: 'totally',
#  364: 'advertised',
#  365: 'let',
#  366: 'thermostat',
#  367: 'stop',
#  368: 'face',
#  369: 'glad',
#  370: 'regret',
#  371: 'decided',
#  372: 'hooked',
#  373: 'kind',
#  374: 'remote',
#  375: 'personal',
#  376: 'handy',
#  377: 'hard',
#  378: 'picture',
#  379: 'speak',
#  380: 'throughout',
#  381: 'lyric',
#  382: 'responds',
#  383: 'power',
#  384: 'cord',
#  385: 'liked',
#  386: 'exactly',
#  387: 'bass',
#  388: 'regular',
#  389: 'along',
#  390: 'surprised',
#  391: 'netflix',
#  392: 'apple',
#  393: 'received',
#  394: 'door',
#  395: 'impressed',
#  396: 'mom',
#  397: 'instead',
#  398: 'security',
#  399: 'entertainment',
#  400: 'thanks',
#  401: 'household',
#  402: 'check',
#  403: 'download',
#  404: 'ready',
#  405: 'bedside',
#  406: 'real',
#  407: 'someone',
#  408: 'flash',
#  409: 'briefing',
#  410: 'smaller',
#  411: 'wrong',
#  412: 'fix',
#  413: 'future',
#  414: 'everyone',
#  415: 'additional',
#  416: 'louder',
#  417: 'channel',
#  418: 'lol',
#  419: 'terrible',
#  420: 'job',
#  421: 'annoying',
#  422: 'loving',
#  423: 'alone',
#  424: 'extra',
#  425: 'group',
#  426: 'quickly',
#  427: 'often',
#  428: 'idea',
#  429: 'run',
#  430: 'functionality',
#  431: 'mostly',
#  432: 'although',
#  433: 'fan',
#  434: 'offer',
#  435: 'blue',
#  436: 'external',
#  437: 'figured',
#  438: 'included',
#  439: 'went',
#  440: 'nightstand',
#  441: 'making',
#  442: 'heard',
#  443: 'step',
#  444: 'box',
#  445: 'told',
#  446: 'wait',
#  447: 'via',
#  448: 'reset',
#  449: 'plan',
#  450: 'intercom',
#  451: 'least',
#  452: 'grandkids',
#  453: 'huge',
#  454: 'dislike',
#  455: 'pick',
#  456: 'cell',
#  457: 'frustrating',
#  458: 'basic',
#  459: 'bose',
#  460: 'upstairs',
#  461: 'beginning',
#  462: 'finally',
#  463: 'streaming',
#  464: 'miss',
#  465: 'purchasing',
#  466: 'upgraded',
#  467: 'low',
#  468: 'played',
#  469: 'drop',
#  470: 'audible',
#  471: 'except',
#  472: 'alexia',
#  473: 'connecting',
#  474: 'bed',
#  475: 'line',
#  476: 'enjoyed',
#  477: 'mini',
#  478: 'difficult',
#  479: 'others',
#  480: 'simply',
#  481: 'load',
#  482: 'tool',
#  483: 'unless',
#  484: 'hoping',
#  485: 'useless',
#  486: 'counter',
#  487: 'large',
#  488: 'saying',
#  489: 'bridge',
#  490: 'specific',
#  491: 'friendly',
#  492: 'running',
#  493: 'sent',
#  494: 'type',
#  495: 'anyone',
#  496: 'traffic',
#  497: 'high',
#  498: 'tooth',
#  499: 'bathroom',
#  500: 'hook',
#  501: 'ordered',
#  502: 'color',
#  503: 'might',
#  504: 'laugh',
#  505: 'extremely',
#  506: 'limited',
#  507: 'stream',
#  508: 'fantastic',
#  509: 'finding',
#  510: 'installation',
#  511: 'sync',
#  512: 'podcasts',
#  513: 'particular',
#  514: 'error',
#  515: 'thinking',
#  516: 'supposed',
#  517: 'happier',
#  518: 'checking',
#  519: 'recognize',
#  520: 'later',
#  521: 'seem',
#  522: 'sonos',
#  523: 'within',
#  524: 'three',
#  525: 'given',
#  526: 'rather',
#  527: 'seeing',
#  528: 'piece',
#  529: 'direction',
#  530: 'turned',
#  531: 'constantly',
#  532: 'repeat',
#  533: 'allow',
#  534: 'knew',
#  535: 'immediately',
#  536: 'front',
#  537: 'mainly',
#  538: 'clearly',
#  539: 'gadget',
#  540: 'grocery',
#  541: 'correctly',
#  542: 'stopped',
#  543: 'either',
#  544: 'point',
#  545: 'member',
#  546: 'compact',
#  547: 'outside',
#  548: 'black',
#  549: 'realize',
#  550: 'toy',
#  551: 'cooking',
#  552: 'story',
#  553: 'quick',
#  554: 'schedule',
#  555: 'contact',
#  556: 'longer',
#  557: 'yes',
#  558: 'process',
#  559: 'kindle',
#  560: 'selection',
#  561: 'expecting',
#  562: 'otherwise',
#  563: 'cheap',
#  564: 'kasa',
#  565: 'battery',
#  566: 'understands',
#  567: 'siri',
#  568: 'continue',
#  569: 'helped',
#  570: 'replace',
#  571: 'digital',
#  572: 'four',
#  573: 'waste',
#  574: 'responsive',
#  575: 'parent',
#  576: 'gotten',
#  577: 'sooner',
#  578: 'source',
#  579: 'software',
#  580: 'language',
#  581: 'range',
#  582: 'outstanding',
#  583: 'currently',
#  584: 'routine',
#  585: 'today',
#  586: 'last',
#  587: 'delivered',
#  588: 'unlimited',
#  589: 'considering',
#  590: 'customer',
#  591: 'roku',
#  592: 'trek',
#  593: 'ok',
#  594: 'completely',
#  595: 'return',
#  596: 'hulu',
#  597: 'entire',
#  598: 'cover',
#  599: 'design',
#  600: 'conversation',
#  601: 'random',
#  602: 'expect',
#  603: 'across',
#  604: 'major',
#  605: 'operate',
#  606: 'card',
#  607: 'place',
#  608: 'dad',
#  609: 'intuitive',
#  610: 'ago',
#  611: 'birthday',
#  612: 'calling',
#  613: 'fault',
#  614: 'basically',
#  615: 'unable',
#  616: 'adapter',
#  617: 'amazed',
#  618: 'condition',
#  619: 'cook',
#  620: 'speaking',
#  621: 'sensitive',
#  622: 'automation',
#  623: 'save',
#  624: 'gone',
#  625: 'event',
#  626: 'dont',
#  627: 'searching',
#  628: 'open',
#  629: 'example',
#  630: 'cycle',
#  631: 'looked',
#  632: 'course',
#  633: 'unfortunately',
#  634: 'maybe',
#  635: 'grandchild',
#  636: 'hand',
#  637: 'improve',
#  638: 'returning',
#  639: 'busy',
#  640: 'primarily',
#  641: 'snooze',
#  642: 'interface',
#  643: 'replaced',
#  644: 'dims',
#  645: 'lock',
#  646: 'believe',
#  647: 'okay',
#  648: 'based',
#  649: 'recognition',
#  650: 'accent',
#  651: 'area',
#  652: 'spend',
#  653: 'potential',
#  654: 'arrived',
#  655: 'child',
#  656: 'become',
#  657: 'hears',
#  658: 'directly',
#  659: 'stay',
#  660: 'installed',
#  661: 'floor',
#  662: 'send',
#  663: 'repair',
#  664: 'iphone',
#  665: 'sister',
#  666: 'slow',
#  667: 'switch',
#  668: 'ai',
#  669: 'world',
#  670: 'linked',
#  671: 'convenience',
#  672: 'lighting',
#  673: 'view',
#  674: 'stereo',
#  675: 'upgrade',
#  676: 'honestly',
#  677: 'interact',
#  678: 'current',
#  679: 'notification',
#  680: 'father',
#  681: 'choice',
#  682: 'guy',
#  683: 'microphone',
#  684: 'close',
#  685: 'answering',
#  686: 'compatible',
#  687: 'third',
#  688: 'outlet',
#  689: 'cute',
#  690: 'hearing',
#  691: 'surprisingly',
#  692: 'awhile',
#  693: 'called',
#  694: 'including',
#  695: 'follow',
#  696: 'clarity',
#  697: 'improvement',
#  698: 'mean',
#  699: 'person',
#  700: 'network',
#  701: 'la',
#  702: 'previous',
#  703: 'expectation',
#  704: 'activated',
#  705: 'forget',
#  706: 'space',
#  707: 'downstairs',
#  708: 'cost',
#  709: 'task',
#  710: 'photo',
#  711: 'calendar',
#  712: 'doorbell',
#  713: 'turning',
#  714: 'fall',
#  715: 'version',
#  716: 'ended',
#  717: 'content',
#  718: 'message',
#  719: 'de',
#  720: 'biggest',
#  721: 'tune',
#  722: 'direct',
#  723: 'cancel',
#  724: 'enabled',
#  725: 'worried',
#  726: 'everyday',
#  727: 'homework',
#  728: 'everywhere',
#  729: 'research',
#  730: 'performs',
#  731: 'neither',
#  732: 'poor',
#  733: 'router',
#  734: 'flawlessly',
#  735: 'kinda',
#  736: 'premium',
#  737: 'guess',
#  738: 'search',
#  739: 'downloaded',
#  740: 'navigate',
#  741: 'beyond',
#  742: 'telling',
#  743: 'solution',
#  744: 'wireless',
#  745: 'decent',
#  746: 'default',
#  747: 'named',
#  748: 'inside',
#  749: 'expensive',
#  750: 'decide',
#  751: 'state',
#  752: 'spent',
#  753: 'returned',
#  754: 'straight',
#  755: 'television',
#  756: 'effective',
#  757: 'requires',
#  758: 'tablet',
#  759: 'party',
#  760: 'move',
#  761: 'addicted',
#  762: 'larger',
#  763: 'library',
#  764: 'stupid',
#  765: 'personally',
#  766: 'instantly',
#  767: 'various',
#  768: 'showing',
#  769: 'dropping',
#  770: 'base',
#  771: 'replacement',
#  772: 'chance',
#  773: 'sleeping',
#  774: 'due',
#  775: 'discovered',
#  776: 'middle',
#  777: 'happens',
#  778: 'excelente',
#  779: 'receive',
#  780: 'figuring',
#  781: 'twice',
#  782: 'rate',
#  783: 'waking',
#  784: 'mother',
#  785: 'choose',
#  786: 'suck',
#  787: 'artist',
#  788: 'website',
#  789: 'location',
#  790: 'exact',
#  791: 'felt',
#  792: 'comfortable',
#  793: 'five',
#  794: 'oh',
#  795: 'correct',
#  796: 'resist',
#  797: 'exploring',
#  798: 'six',
#  799: 'info',
#  800: 'shipping',
#  801: 'mode',
#  802: 'online',
#  803: 'hit',
#  804: 'end',
#  805: 'fidelity',
#  806: 'cam',
#  807: 'communicate',
#  808: 'reading',
#  809: 'inconvenient',
#  810: 'hate',
#  811: 'concern',
#  812: 'giving',
#  813: 'intended',
#  814: 'savvy',
#  815: 'capable',
#  816: 'funny',
#  817: 'sense',
#  818: 'possible',
#  819: 'fairly',
#  820: 'slowly',
#  821: 'knowledge',
#  822: 'discount',
#  823: 'controlling',
#  824: 'simultaneously',
#  825: 'text',
#  826: 'purpose',
#  827: 'wall',
#  828: 'delivery',
#  829: 'rid',
#  830: 'variety',
#  831: 'horrible',
#  832: 'desk',
#  833: 'machine',
#  834: 'advantage',
#  835: 'please',
#  836: 'hope',
#  837: 'waiting',
#  838: 'prior',
#  839: 'randomly',
#  840: 'mic',
#  841: 'equipment',
#  842: 'entertaining',
#  843: 'bother',
#  844: 'created',
#  845: 'opinion',
#  846: 'benefit',
#  847: 'man',
#  848: 'pain',
#  849: 'effort',
#  850: 'refund',
#  851: 'brief',
#  852: 'connects',
#  853: 'lower',
#  854: 'tall',
#  855: 'reach',
#  856: 'weekend',
#  857: 'mine',
#  858: 'bug',
#  859: 'true',
#  860: 'debating',
#  861: 'minor',
#  862: 'late',
#  863: 'plenty',
#  864: 'detail',
#  865: 'custom',
#  866: 'general',
#  867: 'met',
#  868: 'fixture',
#  869: 'report',
#  870: 'basement',
#  871: 'somewhat',
#  872: 'degree',
#  873: 'buyer',
#  874: 'pair',
#  875: 'medium',
#  876: 'rotate',
#  877: 'nest',
#  878: 'discovering',
#  879: 'pleasantly',
#  880: 'elderly',
#  881: 'repeated',
#  882: 'shut',
#  883: 'e',
#  884: 'moment',
#  885: 'directv',
#  886: 'learns',
#  887: 'que',
#  888: 'enjoys',
#  889: 'haha',
#  890: 'waited',
#  891: 'ad',
#  892: 'suppose',
#  893: 'keeping',
#  894: 'temperature',
#  895: 'integrated',
#  896: 'round',
#  897: 'facetime',
#  898: 'disappointment',
#  899: 'form',
#  900: 'sad',
#  901: 'improved',
#  902: 'cloud',
#  903: 'create',
#  904: 'site',
#  905: 'se',
#  906: 'present',
#  907: 'eye',
#  908: 'local',
#  909: 'together',
#  910: 'certain',
#  911: 'described',
#  912: 'thoroughly',
#  913: 'standing',
#  914: 'fit',
#  915: 'trivia',
#  916: 'seriously',
#  917: 'guest',
#  918: 'neat',
#  919: 'enjoyment',
#  920: 'result',
#  921: 'player',
#  922: 'asleep',
#  923: 'na',
#  924: 'model',
#  925: 'manage',
#  926: 'side',
#  927: 'unplugged',
#  928: 'case',
#  929: 'application',
#  930: 'sending',
#  931: 'deck',
#  932: 'comparable',
#  933: 'anymore',
#  934: 'lag',
#  935: 'nearly',
#  936: 'sits',
#  937: 'company',
#  938: 'chromecast',
#  939: 'liking',
#  940: 'powerful',
#  941: 'sitting',
#  942: 'level',
#  943: 'test',
#  944: 'barely',
#  945: 'certified',
#  946: 'answered',
#  947: 'downside',
#  948: 'beat',
#  949: 'tip',
#  950: 'garbage',
#  951: 'im',
#  952: 'lose',
#  953: 'charm',
#  954: 'wonderfully',
#  955: 'greater',
#  956: 'standard',
#  957: 'usb',
#  958: 'privacy',
#  959: 'discover',
#  960: 'rain',
#  961: 'penny',
#  962: 'al',
#  963: 'swipe',
#  964: 'quicker',
#  965: 'delay',
#  966: 'audiobook',
#  967: 'motown',
#  968: 'salsa',
#  969: 'shape',
#  970: 'havent',
#  971: 'remember',
#  972: 'suggestion',
#  973: 'tap',
#  974: 'slightly',
#  975: 'cordless',
#  976: 'older',
#  977: 'training',
#  978: 'likely',
#  979: 'camelot',
#  980: 'alexi',
#  981: 'occasionally',
#  982: 'bonus',
#  983: 'spying',
#  984: 'planning',
#  985: 'helping',
#  986: 'date',
#  987: 'rest',
#  988: 'complete',
#  989: 'speech',
#  990: 'american',
#  991: 'foot',
#  992: 'switched',
#  993: 'eh',
#  994: 'paying',
#  995: 'phrase',
#  996: 'car',
#  997: 'unnecessary',
#  998: 'charge',
#  999: 'cent',
#  1000: 'center',
#  ...}

# %%
vocab_len = len(tok.index_word)
vocab_len
# Out:
# 2945

# %%
seqtrain = tok.texts_to_sequences(xtrain) #step1
seqtrain
# Out:
# [[5, 37, 1741, 180, 1230, 16, 24, 253, 8, 1231, 983],
#  [24, 78, 69, 4, 92, 1232],
#  [1, 10, 50, 203, 238, 278],
#  [],
#  [3,
#   17,
#   42,
#   239,
#   1742,
#   14,
#   260,
#   21,
#   59,
#   120,
#   1743,
#   1744,
#   5,
#   112,
#   69,
#   43,
#   57,
#   6,
#   86,
#   1],
#  [26, 188, 261, 446, 19, 829, 270, 573, 151],
#  [133, 87, 40, 69, 204, 24, 53, 240],
#  [1, 643, 155, 43, 57, 86, 1, 644, 163, 574, 79],
#  [1, 2, 32, 51, 75, 381, 104, 22, 51, 262, 343, 76, 241],
#  [90, 4, 724, 10, 41, 1233, 1234],
#  [1,
#   725,
#   143,
#   181,
#   90,
#   90,
#   2,
#   107,
#   69,
#   47,
#   27,
#   164,
#   5,
#   163,
#   344,
#   37,
#   260,
#   984,
#   78,
#   575,
#   138,
#   726,
#   18,
#   124,
#   1745,
#   1746,
#   25,
#   152,
#   414],
#  [182, 18, 53],
#  [1],
#  [1,
#   18,
#   98,
#   25,
#   576,
#   577,
#   1235,
#   62,
#   100,
#   139,
#   645,
#   183,
#   3,
#   415,
#   45,
#   1236,
#   18,
#   8,
#   985,
#   183,
#   727,
#   481,
#   140,
#   134,
#   73,
#   242,
#   164,
#   44,
#   28,
#   29,
#   243,
#   301,
#   72],
#  [109,
#   382,
#   271,
#   525,
#   79,
#   11,
#   94,
#   447,
#   20,
#   82,
#   31,
#   38,
#   1747,
#   27,
#   74,
#   262,
#   279,
#   68,
#   4,
#   101,
#   10,
#   144,
#   279,
#   55,
#   77,
#   79],
#  [38, 102, 143, 12, 5, 23, 5, 212, 1748, 326, 34],
#  [168, 14, 6, 728],
#  [99, 146],
#  [7,
#   2,
#   88,
#   6,
#   37,
#   729,
#   482,
#   169,
#   830,
#   96,
#   25,
#   8,
#   125,
#   46,
#   100,
#   65,
#   239,
#   416,
#   105,
#   31,
#   646,
#   1237,
#   383,
#   578,
#   272,
#   7,
#   2,
#   273,
#   327,
#   21,
#   70,
#   1238,
#   1749,
#   384,
#   25,
#   58,
#   7,
#   2,
#   13,
#   100,
#   80,
#   60,
#   17],
#  [8,
#   46,
#   63,
#   170,
#   96,
#   170,
#   18,
#   5,
#   1750,
#   30,
#   64,
#   63,
#   263,
#   125,
#   197,
#   63,
#   263,
#   417,
#   197,
#   448,
#   66,
#   143,
#   647,
#   109],
#  [415,
#   4,
#   648,
#   10,
#   50,
#   220,
#   35,
#   181,
#   23,
#   526,
#   184,
#   1239,
#   96,
#   213,
#   56,
#   418,
#   25,
#   80,
#   4,
#   830,
#   302,
#   730],
#  [42, 203, 449, 21, 986, 6],
#  [5, 81, 273, 1751, 987, 10, 988, 302],
#  [156,
#   7,
#   189,
#   450,
#   19,
#   419,
#   1752,
#   1240,
#   280,
#   989,
#   649,
#   579,
#   831,
#   214,
#   1753,
#   990,
#   1754,
#   580,
#   1241,
#   1755,
#   1756,
#   731,
#   650,
#   1757,
#   651,
#   190,
#   16,
#   420,
#   1758,
#   174,
#   38,
#   102,
#   18,
#   1759,
#   165,
#   1240,
#   732,
#   1760,
#   60,
#   165,
#   581,
#   1761,
#   345,
#   1762,
#   991,
#   733,
#   103,
#   992,
#   205,
#   281,
#   1763,
#   1764,
#   1765],
#  [11, 84, 5, 734],
#  [993,
#   133,
#   31,
#   735,
#   1766,
#   26,
#   66,
#   832,
#   57,
#   153,
#   94,
#   260,
#   483,
#   736,
#   1242,
#   994,
#   20,
#   6],
#  [582, 17, 11, 7, 5, 3],
#  [385, 282, 527, 283, 104, 451, 25, 737, 109, 65, 583, 360],
#  [98, 198, 738, 8, 49],
#  [1, 7, 47, 181, 284, 584],
#  [421, 47, 32, 4, 51, 739, 652, 33, 21, 184, 278, 995, 833, 254, 37, 97],
#  [8, 2, 48, 241, 451, 18, 8, 55, 128],
#  [26,
#   484,
#   140,
#   124,
#   834,
#   32,
#   328,
#   76,
#   1243,
#   1244,
#   1767,
#   653,
#   1768,
#   1245,
#   1769,
#   50,
#   7,
#   95,
#   181,
#   32,
#   1770,
#   140,
#   740,
#   328,
#   835],
#  [40, 44, 585, 1246, 100, 996, 7, 56],
#  [1, 4, 836, 128, 39, 346],
#  [3, 9, 52, 36],
#  [1771],
#  [654, 109],
#  [3, 17, 485, 303, 91, 997, 49, 483, 30, 23, 42],
#  [69, 586, 204, 8, 655, 31, 8, 4, 656, 181, 99],
#  [11, 14, 99, 1],
#  [90, 4, 1],
#  [1, 110, 1772, 110, 111, 1773, 837, 191, 347, 152, 110],
#  [741, 240, 208, 452, 1247],
#  [93,
#   2,
#   48,
#   67,
#   28,
#   29,
#   285,
#   587,
#   271,
#   11,
#   286,
#   165,
#   31,
#   144,
#   30,
#   157,
#   85,
#   27,
#   1,
#   742,
#   4,
#   22,
#   6,
#   657,
#   39,
#   221,
#   329,
#   171,
#   34,
#   304],
#  [95, 18, 1248, 215, 33],
#  [1, 21, 129, 244],
#  [90, 30, 60, 422, 3, 18, 4],
#  [1774],
#  [5, 3, 92, 20, 998, 111, 999, 588, 6, 28, 60, 2],
#  [386, 8, 34, 68, 281, 34, 13, 44, 838, 12, 5, 212, 1, 4],
#  [1, 1, 1],
#  [109],
#  [2,
#   32,
#   222,
#   1775,
#   3,
#   34,
#   223,
#   4,
#   23,
#   743,
#   121,
#   175,
#   23,
#   52,
#   361,
#   658,
#   61,
#   3,
#   89,
#   659,
#   328,
#   99],
#  [17, 55, 839, 197, 163],
#  [416, 13, 44, 224, 67, 744, 85, 56],
#  [1243,
#   528,
#   153,
#   1000,
#   216,
#   39,
#   1249,
#   113,
#   486,
#   840,
#   15,
#   100,
#   128,
#   529,
#   36,
#   9,
#   287,
#   16,
#   144,
#   2,
#   447,
#   119,
#   1001,
#   1250,
#   64,
#   101,
#   2,
#   1776,
#   9,
#   1777,
#   1002,
#   841,
#   16,
#   581,
#   745,
#   387,
#   9,
#   1778,
#   1251,
#   842,
#   255,
#   176,
#   843,
#   1779,
#   1252,
#   1253,
#   288,
#   5,
#   3,
#   1780,
#   125,
#   90,
#   2,
#   10,
#   25,
#   1003,
#   1004,
#   125,
#   289,
#   2,
#   487,
#   1781,
#   1254,
#   423,
#   25,
#   152,
#   388,
#   2,
#   225,
#   528,
#   97,
#   36,
#   287,
#   1782,
#   1255,
#   1783,
#   1256,
#   1005,
#   16,
#   1784,
#   1785,
#   486,
#   1786,
#   45,
#   1787,
#   1788,
#   80,
#   1789,
#   272,
#   217,
#   245,
#   348,
#   226,
#   74,
#   660,
#   389,
#   424,
#   12,
#   38,
#   262,
#   74,
#   216,
#   39,
#   661,
#   279,
#   530,
#   27,
#   54,
#   4,
#   94,
#   10,
#   746,
#   330,
#   74,
#   1790,
#   90,
#   27,
#   177,
#   27,
#   1257,
#   661,
#   279,
#   530,
#   12,
#   27,
#   488,
#   4,
#   55,
#   177,
#   27,
#   4,
#   82,
#   844,
#   90,
#   27,
#   177,
#   27,
#   747,
#   425,
#   27,
#   55,
#   279,
#   74,
#   1791,
#   54,
#   4,
#   55,
#   27,
#   390,
#   246,
#   74,
#   144,
#   2,
#   48,
#   224,
#   67,
#   135,
#   25,
#   60,
#   67,
#   489,
#   94,
#   661,
#   279,
#   383,
#   157,
#   1006,
#   349,
#   224,
#   658,
#   748,
#   74,
#   390,
#   253,
#   8,
#   1792,
#   1793,
#   10,
#   247,
#   287,
#   140,
#   8,
#   9,
#   29,
#   4,
#   227,
#   481,
#   426,
#   290,
#   104,
#   122,
#   490,
#   331,
#   20,
#   6,
#   31,
#   3,
#   100,
#   177,
#   29,
#   1794,
#   60,
#   28,
#   29,
#   92,
#   115,
#   749,
#   589,
#   2,
#   845,
#   994,
#   736,
#   2,
#   48,
#   750,
#   362,
#   1795,
#   9,
#   125,
#   1253,
#   288,
#   1258,
#   92,
#   453,
#   846,
#   289,
#   224,
#   67,
#   226,
#   74,
#   1796,
#   1007,
#   84,
#   449,
#   1008,
#   27,
#   84,
#   661,
#   279,
#   347,
#   152,
#   60,
#   2,
#   13,
#   86],
#  [93, 847, 1797, 422],
#  [5, 81],
#  [454, 1259, 332, 21],
#  [18, 89, 133, 19, 12, 62, 133],
#  [147, 81],
#  [109],
#  [148, 8, 17, 156, 51, 123, 391, 64, 11, 228],
#  [],
#  [107,
#   1,
#   51,
#   55,
#   27,
#   1009,
#   1010,
#   23,
#   31,
#   19,
#   52,
#   361,
#   1798,
#   280,
#   751,
#   221,
#   229,
#   4,
#   121],
#  [3, 17],
#  [1, 115, 133],
#  [2,
#   181,
#   5,
#   112,
#   226,
#   67,
#   1260,
#   147,
#   230,
#   274,
#   752,
#   248,
#   61,
#   305,
#   306,
#   12,
#   662,
#   663,
#   184,
#   1799,
#   27,
#   848,
#   448,
#   27,
#   74,
#   124,
#   21,
#   19,
#   448,
#   752,
#   248,
#   54,
#   590,
#   350,
#   491,
#   333,
#   307,
#   141,
#   2,
#   30,
#   157,
#   279],
#  [3, 72, 3, 17, 149, 141, 95, 92, 5, 35, 591],
#  [11,
#   14,
#   87,
#   18,
#   123,
#   208,
#   45,
#   576,
#   41,
#   190,
#   11,
#   7,
#   347,
#   1261,
#   1262,
#   1800,
#   1011,
#   270,
#   384,
#   16],
#  [8,
#   111,
#   183,
#   56,
#   531,
#   532,
#   68,
#   4,
#   192,
#   256,
#   29,
#   1801,
#   1263,
#   657,
#   192,
#   1802,
#   10,
#   26,
#   133,
#   8,
#   1264,
#   19,
#   102,
#   136,
#   249,
#   5,
#   101,
#   1803,
#   427,
#   7,
#   10],
#  [8, 6, 334],
#  [81],
#  [2, 13, 1012, 15, 21, 29, 60, 143, 17, 136, 849],
#  [5, 8, 12],
#  [308],
#  [753, 2, 13, 78, 850, 753, 12, 351, 62, 850, 351, 75],
#  [1, 124, 1265, 7, 11, 14],
#  [44,
#   129,
#   1,
#   161,
#   25,
#   38,
#   12,
#   1013,
#   22,
#   6,
#   1266,
#   28,
#   6,
#   199,
#   31,
#   158,
#   34,
#   851,
#   68,
#   291],
#  [1, 428, 136, 592, 264, 23, 140, 3, 1267, 580, 5, 1804],
#  [],
#  [8, 4, 10, 56, 285, 72, 20, 28, 29, 1268],
#  [12, 103, 42, 60, 82, 20, 1805, 664, 82, 72, 10, 81],
#  [26,
#   1,
#   13,
#   107,
#   852,
#   39,
#   8,
#   231,
#   335,
#   148,
#   853,
#   125,
#   130,
#   144,
#   15,
#   111,
#   10,
#   25,
#   3,
#   352,
#   423,
#   125,
#   148,
#   8,
#   854,
#   2,
#   13,
#   455,
#   77,
#   16,
#   854,
#   363,
#   1,
#   25,
#   152],
#  [1014, 25, 533, 4, 94, 1806, 665, 392, 456, 305, 306, 1015, 1016, 492],
#  [11, 14, 292, 70, 5, 364],
#  [275, 8, 51, 7, 88, 6, 98, 534, 240],
#  [38,
#   2,
#   13,
#   285,
#   28,
#   29,
#   329,
#   217,
#   309,
#   29,
#   14,
#   535,
#   47,
#   147,
#   212,
#   112,
#   14,
#   11,
#   754,
#   232,
#   26,
#   1269,
#   419,
#   349,
#   185,
#   353,
#   73,
#   193,
#   105,
#   7,
#   2,
#   13,
#   257,
#   80,
#   1270,
#   198,
#   144,
#   165,
#   286,
#   731,
#   5,
#   457,
#   78,
#   7,
#   2,
#   13,
#   26,
#   98,
#   46,
#   12,
#   103,
#   743,
#   835,
#   365,
#   66],
#  [593, 23, 76, 149, 141, 108, 755, 108, 4, 354, 96, 79, 114, 855, 20, 856],
#  [26, 134, 73, 3, 15, 11, 14],
#  [14, 2, 13, 147, 248, 1807, 594, 60, 143, 493, 175, 595, 29, 393],
#  [8,
#   481,
#   596,
#   310,
#   31,
#   666,
#   66,
#   198,
#   311,
#   1808,
#   12,
#   5,
#   112,
#   149,
#   64,
#   141,
#   124,
#   1271,
#   481,
#   200],
#  [1,
#   18,
#   492,
#   597,
#   23,
#   64,
#   27,
#   366,
#   536,
#   394,
#   1272,
#   1273,
#   180,
#   1,
#   117,
#   1274,
#   18,
#   37,
#   199,
#   362,
#   26,
#   1017,
#   1275,
#   290,
#   30,
#   10,
#   85,
#   597,
#   23,
#   8,
#   153,
#   136,
#   592,
#   747,
#   857,
#   264,
#   19,
#   253,
#   83,
#   10,
#   30,
#   206],
#  [537, 7, 6, 53, 21, 26, 274, 312, 54],
#  [3, 10],
#  [287,
#   207,
#   538,
#   858,
#   301,
#   21,
#   63,
#   1809,
#   102,
#   177,
#   292,
#   276,
#   18,
#   367,
#   1810,
#   293,
#   257,
#   100,
#   63,
#   22,
#   189,
#   31,
#   91,
#   21,
#   19,
#   1018,
#   63,
#   667,
#   27,
#   110,
#   31,
#   747,
#   859,
#   538,
#   668,
#   1267,
#   580,
#   1811,
#   24,
#   395],
#  [128, 1812, 135, 25, 48, 114, 396, 153, 19, 118],
#  [22, 3],
#  [11, 14],
#  [3, 8, 34],
#  [105, 19, 265, 1813, 108, 1258, 290, 250, 1276, 10, 1277],
#  [241, 65, 4, 724, 539, 8, 1278, 57, 368, 95],
#  [1279, 3, 17],
#  [1, 123, 214, 1280, 4, 1019, 12, 163, 117, 4, 201, 456, 61],
#  [218, 17],
#  [1,
#   2,
#   32,
#   166,
#   52,
#   361,
#   183,
#   452,
#   113,
#   429,
#   192,
#   4,
#   159,
#   540,
#   126,
#   7,
#   47,
#   11,
#   14],
#  [860,
#   136,
#   335,
#   12,
#   1281,
#   67,
#   1282,
#   247,
#   430,
#   5,
#   67,
#   458,
#   430,
#   5,
#   150,
#   42,
#   102,
#   294,
#   14,
#   47,
#   62,
#   397,
#   12,
#   1283,
#   250,
#   106,
#   1020,
#   293,
#   21,
#   80,
#   1284,
#   283,
#   101,
#   347,
#   1814,
#   861,
#   106,
#   227,
#   1285,
#   54,
#   541,
#   1286,
#   12,
#   102,
#   532,
#   15,
#   3,
#   36,
#   246,
#   598,
#   39,
#   1287,
#   599,
#   1815,
#   1288,
#   40,
#   1816,
#   842,
#   600],
#  [1],
#  [139],
#  [116, 137, 5, 3, 1289],
#  [11, 228, 256, 15, 355, 12, 136, 587, 862, 1021],
#  [422, 1022, 1817, 596, 542, 108, 1818, 5, 543, 295, 667, 192, 233, 346],
#  [5, 35, 1023, 18, 107],
#  [172, 67, 44, 28, 29, 226, 222, 74, 5, 3, 159, 258, 1290, 67],
#  [11, 14, 7],
#  [262,
#   12,
#   86,
#   22,
#   6,
#   68,
#   174,
#   59,
#   31,
#   43,
#   209,
#   174,
#   194,
#   35,
#   57,
#   189,
#   22,
#   494,
#   6,
#   62,
#   189,
#   313,
#   178,
#   45,
#   68,
#   291,
#   66,
#   44,
#   389,
#   80,
#   83],
#  [11, 228],
#  [172,
#   1819,
#   89,
#   30,
#   15,
#   43,
#   398,
#   1820,
#   1821,
#   1000,
#   311,
#   669,
#   163,
#   248,
#   431,
#   1822,
#   1823,
#   24,
#   220,
#   669,
#   80,
#   862,
#   163,
#   9,
#   83,
#   137,
#   122,
#   41,
#   1291,
#   431,
#   54,
#   10,
#   1824,
#   859,
#   1825],
#  [1024,
#   49,
#   140,
#   16,
#   15,
#   863,
#   387,
#   6,
#   24,
#   42,
#   5,
#   668,
#   1025,
#   601,
#   96,
#   127,
#   1014,
#   61,
#   41,
#   35,
#   2,
#   24,
#   19,
#   87,
#   1826,
#   130,
#   845],
#  [432,
#   177,
#   2,
#   10,
#   24,
#   207,
#   243,
#   91,
#   302,
#   10,
#   93,
#   1827,
#   9,
#   36,
#   234,
#   119,
#   240,
#   586,
#   163,
#   1828,
#   42,
#   1026,
#   864,
#   430,
#   10,
#   451,
#   544,
#   234],
#  [109],
#  [1],
#  [5, 37, 356, 152, 495],
#  [1],
#  [3, 17],
#  [42, 19, 35, 85, 865, 336, 314, 50, 57, 229, 87, 866, 3, 10, 369, 44],
#  [40, 41, 53, 7],
#  [83, 399, 42],
#  [1829,
#   40,
#   251,
#   277,
#   96,
#   90,
#   29,
#   14,
#   284,
#   43,
#   856,
#   252,
#   331,
#   194,
#   32,
#   601,
#   104,
#   284,
#   1027,
#   1028,
#   59,
#   194,
#   1292,
#   68,
#   89,
#   100,
#   1830,
#   496,
#   19,
#   12,
#   670,
#   61,
#   190],
#  [147, 1831],
#  [1, 2],
#  [84,
#   10,
#   168,
#   756,
#   315,
#   75,
#   415,
#   140,
#   159,
#   314,
#   4,
#   3,
#   1832,
#   106,
#   314,
#   344,
#   1029,
#   42,
#   867,
#   80,
#   1030,
#   244,
#   99],
#  [5, 3],
#  [1833, 9, 5, 3],
#  [11, 14, 94, 30, 10, 337],
#  [93,
#   2,
#   48,
#   67,
#   46,
#   671,
#   229,
#   4,
#   55,
#   27,
#   279,
#   348,
#   226,
#   27,
#   74,
#   1031,
#   868,
#   156,
#   4,
#   85,
#   5,
#   3,
#   160,
#   2,
#   13,
#   651,
#   1031,
#   2,
#   48,
#   67,
#   86,
#   189,
#   279,
#   113,
#   1293,
#   1032,
#   157,
#   1294,
#   27,
#   868,
#   279,
#   1293,
#   86,
#   1295,
#   348,
#   226,
#   27,
#   74,
#   1032,
#   67,
#   748,
#   2,
#   48,
#   51,
#   22,
#   6,
#   14,
#   43,
#   19,
#   59,
#   869,
#   1033,
#   18,
#   10,
#   2,
#   13,
#   757,
#   157,
#   327,
#   2,
#   48,
#   757,
#   1295,
#   348,
#   27,
#   74,
#   660,
#   27,
#   868,
#   5,
#   18,
#   454,
#   497,
#   72,
#   27,
#   74,
#   1290,
#   50,
#   27,
#   5,
#   388,
#   27,
#   74,
#   1031,
#   1294,
#   27,
#   868,
#   5,
#   4,
#   2,
#   48,
#   67,
#   497,
#   72,
#   74,
#   1,
#   2,
#   48,
#   224,
#   67],
#  [1834,
#   433,
#   2,
#   1835,
#   1,
#   545,
#   4,
#   99,
#   2,
#   2,
#   13,
#   2,
#   48,
#   34,
#   1836,
#   2,
#   71,
#   128,
#   1837,
#   1838,
#   1,
#   253,
#   137,
#   2,
#   71,
#   1296,
#   41,
#   97,
#   1034,
#   3,
#   316,
#   36,
#   602,
#   21,
#   1839,
#   272,
#   546,
#   116,
#   137,
#   38,
#   94,
#   459,
#   1840],
#  [3, 9, 52, 48, 3, 258, 4, 434, 45, 55, 27],
#  [1,
#   2,
#   1,
#   38,
#   28,
#   29,
#   370,
#   1,
#   94,
#   235,
#   75,
#   536,
#   394,
#   1841,
#   183,
#   8,
#   527,
#   381,
#   104,
#   1297,
#   389],
#  [41, 1, 108, 78, 18, 14, 1, 540, 126, 82],
#  [314,
#   22,
#   20,
#   6,
#   547,
#   1298,
#   1842,
#   31,
#   69,
#   435,
#   498,
#   94,
#   2,
#   48,
#   447,
#   4,
#   82,
#   758,
#   436,
#   15,
#   759,
#   1843,
#   1035,
#   449,
#   94,
#   10,
#   366,
#   672,
#   23,
#   10],
#  [41, 54, 1],
#  [14, 11],
#  [156, 7, 57, 86, 1844, 116, 75, 1036, 1006, 105, 263],
#  [106, 5, 97, 3],
#  [2, 148, 42, 12],
#  [32, 274],
#  [188, 33],
#  [353, 73, 351, 217, 16, 21, 109],
#  [147, 364, 400],
#  [93,
#   32,
#   166,
#   328,
#   251,
#   99,
#   1845,
#   760,
#   301,
#   89,
#   603,
#   1037,
#   241,
#   527,
#   368,
#   600],
#  [4, 665, 177, 13],
#  [251,
#   156,
#   222,
#   1846,
#   274,
#   16,
#   1038,
#   155,
#   371,
#   100,
#   2,
#   13,
#   332,
#   222,
#   1039,
#   16,
#   15,
#   146,
#   129,
#   58,
#   145,
#   91,
#   18,
#   198],
#  [1, 33],
#  [97, 3],
#  [44,
#   129,
#   1,
#   161,
#   25,
#   38,
#   12,
#   1013,
#   22,
#   6,
#   1266,
#   28,
#   6,
#   199,
#   31,
#   158,
#   34,
#   851,
#   68,
#   291],
#  [88, 6, 14, 154],
#  [2, 156, 13, 86, 45, 238, 14, 186, 2],
#  [17, 97, 1847, 39, 1, 1299, 38, 396, 12, 129, 28, 29, 105, 446, 7],
#  [156,
#   222,
#   13,
#   222,
#   499,
#   288,
#   548,
#   1300,
#   534,
#   549,
#   384,
#   157,
#   31,
#   548,
#   156,
#   222,
#   384,
#   157],
#  [8, 97, 35, 186, 2, 1301, 155, 2, 870, 99, 39, 58, 9],
#  [1, 1, 1],
#  [1],
#  [1, 22, 266, 9, 535, 63],
#  [17,
#   1040,
#   871,
#   308,
#   20,
#   1041,
#   1042,
#   250,
#   673,
#   18,
#   131,
#   1848,
#   1849,
#   1850,
#   362,
#   17,
#   60,
#   483,
#   1043,
#   673,
#   1851,
#   20],
#  [8, 830, 258, 2, 32, 434],
#  [83],
#  [4, 1044],
#  [761, 18],
#  [317,
#   9,
#   36,
#   3,
#   431,
#   7,
#   79,
#   127,
#   111,
#   13,
#   372,
#   674,
#   206,
#   22,
#   6,
#   293,
#   244,
#   13,
#   1045,
#   316,
#   36,
#   1302,
#   373,
#   18,
#   100,
#   195,
#   137,
#   2,
#   50,
#   130,
#   500,
#   762,
#   15],
#  [1],
#  [41, 604, 106],
#  [42, 1852, 1303, 872, 605, 18, 114, 175, 346],
#  [1, 1, 1, 38, 28, 29, 873, 1853, 44, 1, 90, 1854],
#  [38, 102, 12, 113, 1855, 39, 3, 42, 343, 42, 66, 192, 24, 53, 47],
#  [70,
#   4,
#   293,
#   29,
#   87,
#   40,
#   34,
#   550,
#   8,
#   34,
#   401,
#   545,
#   184,
#   171,
#   170,
#   1856,
#   846,
#   172],
#  [5, 3],
#  [1, 247, 460, 86],
#  [16,
#   51,
#   88,
#   128,
#   1304,
#   104,
#   21,
#   20,
#   1857,
#   763,
#   461,
#   66,
#   47,
#   2,
#   32,
#   434,
#   37,
#   199,
#   72,
#   4,
#   307],
#  [1858, 278],
#  [455, 77, 483, 1305, 21],
#  [355,
#   65,
#   5,
#   14,
#   462,
#   44,
#   9,
#   36,
#   95,
#   44,
#   5,
#   3,
#   402,
#   59,
#   63,
#   551,
#   96,
#   113,
#   22,
#   189,
#   62,
#   6,
#   295,
#   675,
#   2,
#   48,
#   35,
#   9],
#  [1, 169, 764, 96, 68, 59, 19, 1306],
#  [99, 146],
#  [],
#  [95, 463, 10, 1307],
#  [44, 3, 9, 387, 5, 21, 24, 1308, 464, 1309, 18],
#  [40, 173, 454, 41, 8, 671],
#  [3, 223, 2, 48],
#  [1, 11, 7, 12, 95, 28, 29, 73, 162],
#  [149, 1859, 33, 1860, 874, 15],
#  [44,
#   28,
#   29,
#   437,
#   75,
#   1861,
#   676,
#   26,
#   62,
#   8,
#   765,
#   1862,
#   56,
#   179,
#   735,
#   1046,
#   676,
#   1,
#   8,
#   89,
#   669,
#   114,
#   146,
#   33,
#   501,
#   19,
#   32,
#   97,
#   8,
#   217,
#   1863,
#   1864,
#   1865,
#   318,
#   200,
#   10,
#   1310,
#   71,
#   76,
#   843,
#   432,
#   122,
#   115,
#   33,
#   728,
#   178,
#   181,
#   216,
#   39,
#   372,
#   119,
#   1250,
#   54,
#   22,
#   104,
#   62,
#   737,
#   46,
#   455,
#   1866,
#   66,
#   33,
#   238,
#   677,
#   875,
#   70,
#   77,
#   526,
#   1311,
#   265,
#   12,
#   18,
#   433,
#   23,
#   76,
#   606,
#   26,
#   876,
#   33,
#   31,
#   876,
#   118,
#   6,
#   1,
#   336,
#   59,
#   88,
#   76,
#   256,
#   31,
#   26,
#   182,
#   4,
#   51,
#   68,
#   1292,
#   3,
#   140,
#   403,
#   68,
#   496,
#   170,
#   607,
#   208,
#   330,
#   54,
#   4,
#   158,
#   496,
#   575,
#   68,
#   95,
#   1312,
#   21,
#   1867,
#   678,
#   496,
#   1047,
#   575,
#   1868,
#   575,
#   5,
#   5,
#   26,
#   5,
#   12,
#   18,
#   282,
#   1869,
#   13,
#   71,
#   13,
#   27,
#   170,
#   502,
#   351,
#   679,
#   1870,
#   71,
#   26,
#   33,
#   351,
#   679,
#   190,
#   13,
#   11,
#   68,
#   192,
#   587,
#   25,
#   152,
#   20,
#   386,
#   13,
#   71,
#   13,
#   27,
#   502,
#   105,
#   71,
#   89,
#   79,
#   4,
#   19,
#   435,
#   235,
#   50,
#   235,
#   1871,
#   351,
#   1313,
#   3,
#   10,
#   267,
#   232,
#   1314,
#   23,
#   205,
#   160,
#   267,
#   1315,
#   289,
#   30,
#   157,
#   120,
#   656,
#   23,
#   1316,
#   397,
#   1872,
#   105,
#   1873,
#   366,
#   465,
#   877,
#   1317,
#   1874,
#   1048],
#  [24, 878, 2],
#  [47, 3, 1, 4, 77, 374],
#  [24, 53, 240, 41, 115, 115, 115, 16],
#  [879,
#   390,
#   9,
#   36,
#   2,
#   196,
#   433,
#   1049,
#   387,
#   503,
#   1318,
#   127,
#   653,
#   85,
#   23,
#   145,
#   1050,
#   1319,
#   23,
#   30,
#   23,
#   77,
#   649,
#   1051,
#   1320,
#   40,
#   370,
#   73,
#   3,
#   1052,
#   263,
#   296,
#   63,
#   22,
#   104,
#   142,
#   382,
#   766,
#   880,
#   146,
#   12,
#   25,
#   3,
#   129,
#   144,
#   165,
#   168,
#   7,
#   62,
#   588,
#   6,
#   85,
#   130,
#   20,
#   28,
#   736,
#   260,
#   1321,
#   221,
#   375,
#   1322,
#   45,
#   600,
#   2,
#   1323,
#   54,
#   2,
#   162,
#   504,
#   293,
#   21,
#   63,
#   68,
#   291,
#   68,
#   351,
#   164,
#   20,
#   28,
#   1053,
#   172,
#   505,
#   376],
#  [5, 3, 1, 1054, 251, 1324, 318, 1875, 418],
#  [95, 680, 29, 129, 608, 1325, 396, 4, 12, 117, 881, 552, 114, 232],
#  [395, 168, 7],
#  [134,
#   15,
#   3,
#   185,
#   87,
#   21,
#   22,
#   6,
#   292,
#   50,
#   1046,
#   1876,
#   367,
#   268,
#   167,
#   23,
#   33,
#   35],
#  [730,
#   115,
#   33,
#   109,
#   207,
#   1326,
#   1327,
#   42,
#   22,
#   767,
#   373,
#   6,
#   80,
#   1328,
#   20,
#   6,
#   350,
#   210,
#   6,
#   681,
#   254,
#   506,
#   80,
#   1329,
#   63,
#   220,
#   6,
#   1055,
#   245,
#   389,
#   2,
#   73,
#   1330,
#   768,
#   580,
#   42,
#   7],
#  [8],
#  [3,
#   17,
#   91,
#   16,
#   1331,
#   11,
#   84,
#   85,
#   609,
#   754,
#   232,
#   213,
#   438,
#   1056,
#   218,
#   147,
#   212,
#   33,
#   182,
#   17,
#   152],
#  [1877, 143, 5, 3],
#  [3, 17, 1057, 11, 7],
#  [385,
#   9,
#   1332,
#   357,
#   424,
#   151,
#   220,
#   1333,
#   104,
#   197,
#   5,
#   1334,
#   4,
#   22,
#   1335,
#   104,
#   210,
#   22,
#   1336,
#   1337,
#   338,
#   1058],
#  [1021, 1338, 4],
#  [9, 36, 16, 98, 4, 46, 169, 96],
#  [269, 161, 328, 374, 882, 64],
#  [70, 507, 20, 28, 391],
#  [90,
#   393,
#   17,
#   3,
#   249,
#   204,
#   610,
#   10,
#   1878,
#   52,
#   1059,
#   205,
#   163,
#   1060,
#   99,
#   62,
#   50,
#   130,
#   1879,
#   533,
#   52,
#   658,
#   23,
#   71,
#   10,
#   166,
#   1880],
#  [5, 16, 249, 72, 439, 204, 93],
#  [92, 26, 33, 22, 6, 169, 764, 96, 462, 51, 500, 366, 75, 72, 769, 8, 1061],
#  [113, 3, 132, 6, 52, 121, 251, 1054, 183, 26, 1324],
#  [525,
#   202,
#   21,
#   611,
#   129,
#   608,
#   1,
#   63,
#   4,
#   200,
#   169,
#   48,
#   16,
#   727,
#   93,
#   12,
#   28,
#   29,
#   499,
#   78,
#   404,
#   5,
#   88,
#   6,
#   770,
#   1881,
#   1882,
#   771,
#   57,
#   189,
#   48,
#   2,
#   13,
#   163,
#   352,
#   43,
#   57],
#  [40, 677],
#  [3, 1],
#  [],
#  [3,
#   6,
#   52,
#   612,
#   113,
#   154,
#   295,
#   1339,
#   185,
#   339,
#   397,
#   136,
#   18,
#   131,
#   23,
#   76,
#   1883,
#   1340,
#   317,
#   1341,
#   346,
#   20,
#   1013,
#   145,
#   882],
#  [44,
#   16,
#   191,
#   5,
#   3,
#   28,
#   84,
#   239,
#   848,
#   613,
#   1342,
#   198,
#   350,
#   147,
#   3,
#   58,
#   9,
#   116,
#   15],
#  [22, 6, 332],
#  [1, 17, 7, 55, 27, 169, 553, 96],
#  [463, 11, 1, 123, 391, 86, 64, 1062],
#  [355,
#   834,
#   28,
#   1884,
#   371,
#   124,
#   772,
#   73,
#   12,
#   182,
#   49,
#   172,
#   1058,
#   73,
#   102,
#   37,
#   199,
#   151,
#   97,
#   3,
#   440,
#   128,
#   163,
#   262,
#   1885,
#   773,
#   6,
#   134,
#   590],
#  [2, 16],
#  [47, 109],
#  [1, 117, 6, 24, 184, 171, 47],
#  [11, 14, 1343, 1],
#  [5, 1063, 218, 9],
#  [187, 1, 113, 7, 551, 15, 83],
#  [26, 134, 73, 3, 15, 11, 14],
#  [],
#  [15, 255, 167, 23],
#  [58, 15],
#  [107, 10, 23, 195, 308, 173, 174, 883, 61, 169, 1886, 884, 96],
#  [5, 364, 54, 4, 227, 53, 3, 53, 18, 4],
#  [1, 405, 368, 1887, 163, 1344, 773],
#  [741, 107],
#  [505, 11, 7, 992, 221, 885, 7, 507],
#  [3, 17],
#  [13, 466, 8, 317, 1064, 213],
#  [1,
#   78,
#   7,
#   4,
#   78,
#   7,
#   77,
#   197,
#   169,
#   92,
#   198,
#   467,
#   1888,
#   77,
#   1065,
#   421,
#   258,
#   414,
#   1889,
#   215,
#   1890,
#   88,
#   335,
#   357,
#   1066,
#   392,
#   682],
#  [5, 16, 683, 16, 35, 2, 17],
#  [432,
#   1891,
#   834,
#   91,
#   2,
#   49,
#   12,
#   843,
#   292,
#   201,
#   45,
#   297,
#   200,
#   45,
#   684,
#   209,
#   283,
#   2,
#   263,
#   4,
#   774,
#   1892,
#   111,
#   10],
#  [],
#  [160, 2, 48, 38, 12, 86, 1, 302],
#  [5, 1063, 218, 9],
#  [44,
#   230,
#   610,
#   428,
#   138,
#   85,
#   30,
#   74,
#   308,
#   685,
#   96,
#   78,
#   284,
#   59,
#   41,
#   21,
#   209,
#   10,
#   63,
#   96,
#   1893,
#   79,
#   122,
#   54,
#   55,
#   614,
#   1345,
#   427,
#   615,
#   169,
#   458,
#   457,
#   4,
#   5,
#   526,
#   441,
#   203,
#   25,
#   595,
#   1894,
#   595,
#   1346,
#   1895],
#  [5, 212],
#  [12, 172],
#  [51, 7, 111, 39, 159, 4, 39],
#  [1,
#   18,
#   492,
#   597,
#   23,
#   64,
#   27,
#   366,
#   536,
#   394,
#   1272,
#   1273,
#   180,
#   1,
#   117,
#   1274,
#   18,
#   37,
#   199,
#   362,
#   26,
#   1017,
#   1275,
#   290,
#   30,
#   10,
#   85,
#   597,
#   23,
#   8,
#   153,
#   136,
#   592,
#   747,
#   857,
#   264,
#   19,
#   253,
#   83,
#   10,
#   30,
#   206],
#  [40, 677],
#  [38,
#   85,
#   1347,
#   755,
#   5,
#   37,
#   484,
#   21,
#   85,
#   1347,
#   775,
#   18,
#   4,
#   22,
#   6,
#   63,
#   3,
#   9,
#   4,
#   22,
#   236,
#   22,
#   189,
#   313,
#   22,
#   155,
#   21,
#   189,
#   208,
#   8,
#   211,
#   1896,
#   4,
#   91,
#   294,
#   159,
#   314,
#   29,
#   468,
#   1897,
#   3,
#   40,
#   31,
#   4,
#   85,
#   401,
#   1898,
#   93,
#   4,
#   686,
#   383,
#   1899,
#   85,
#   672,
#   433,
#   64,
#   1067,
#   267,
#   232,
#   1900,
#   1348,
#   31,
#   159,
#   4,
#   1067,
#   1901,
#   6,
#   22,
#   39,
#   1067,
#   1349],
#  [8, 1068, 229, 96, 8, 63, 84, 554, 144, 279],
#  [83, 17, 24, 1350, 18],
#  [9, 508, 1902, 6, 8, 1903, 23, 85, 9, 1904, 1069, 288, 31, 68, 4, 125],
#  [1, 1],
#  [1, 13, 12, 2, 875, 137, 39, 255, 176, 80, 436, 15, 432, 7, 436, 13],
#  [187, 1, 1070, 337, 549, 374, 438, 77, 374, 269, 369, 1070, 162, 73],
#  [11, 14, 94, 30, 10, 337],
#  [136,
#   186,
#   854,
#   2,
#   13,
#   71,
#   32,
#   18,
#   509,
#   103,
#   15,
#   71,
#   70,
#   469,
#   197,
#   442,
#   71,
#   1905,
#   1906,
#   77,
#   1351,
#   1352,
#   9,
#   1071,
#   1907,
#   1908,
#   112,
#   9,
#   197,
#   532,
#   209,
#   283,
#   21,
#   991,
#   221,
#   48,
#   12,
#   352,
#   101,
#   2,
#   13,
#   186,
#   2,
#   32,
#   33,
#   35,
#   9,
#   36,
#   12,
#   185,
#   38,
#   2,
#   32],
#  [146],
#  [8, 34, 16, 1909],
#  [38, 499, 88, 1353, 1],
#  [33,
#   40,
#   22,
#   63,
#   14,
#   43,
#   209,
#   194,
#   100,
#   68,
#   4,
#   55,
#   4,
#   886,
#   96,
#   63,
#   22,
#   6,
#   63,
#   22,
#   20,
#   6,
#   1910,
#   209,
#   776,
#   163,
#   55,
#   27,
#   63,
#   4,
#   21,
#   62,
#   678,
#   59,
#   68,
#   63,
#   114,
#   1911,
#   66,
#   121,
#   244,
#   1912,
#   69,
#   12,
#   190,
#   297,
#   46,
#   555],
#  [1, 5, 3, 441, 23, 1354],
#  [83, 17, 24, 1350, 18],
#  [26, 182, 51, 50, 332, 178, 6, 777, 317, 21],
#  [778, 1913, 1914, 883, 887, 1915, 1355, 1072],
#  [188, 24, 53, 79, 1916, 12, 457, 106, 250, 491, 184, 14, 77, 649, 401],
#  [8, 66, 6, 451, 744, 125, 497],
#  [47],
#  [1, 251, 888, 742, 4, 889],
#  [24, 53, 7, 8, 41, 468, 6, 237, 293, 142, 317],
#  [2,
#   13,
#   108,
#   62,
#   86,
#   1917,
#   116,
#   435,
#   498,
#   15,
#   586,
#   1918,
#   439,
#   266,
#   9,
#   1919,
#   1055,
#   2,
#   13,
#   984,
#   13,
#   55,
#   86,
#   279,
#   779,
#   30,
#   157,
#   501],
#  [129],
#  [1, 53, 534, 18, 1356, 24, 780, 47, 5, 41, 11, 7, 210, 50, 504, 21],
#  [12, 114, 113, 1920],
#  [110, 556, 5, 230, 7, 94, 165, 1921, 448, 332],
#  [1],
#  [4, 115, 1357],
#  [3, 10],
#  [],
#  [3, 34, 244],
#  [1073, 55],
#  [5, 81, 1922, 1923, 10, 1, 4, 108, 441, 23, 30],
#  [1, 18, 5, 3, 183, 1],
#  [26,
#   8,
#   110,
#   160,
#   2,
#   13,
#   73,
#   348,
#   226,
#   74,
#   217,
#   48,
#   465,
#   48,
#   21,
#   7,
#   195,
#   240,
#   74,
#   192,
#   233,
#   7,
#   2,
#   13,
#   55,
#   86,
#   27,
#   26,
#   8,
#   48,
#   3,
#   651,
#   41,
#   158,
#   136],
#  [466, 90, 225, 261, 66, 890, 211, 1],
#  [160, 2, 13, 2, 45, 35, 1924, 9, 31, 84, 365, 61, 121, 162, 555, 126, 3],
#  [11, 14, 250, 491],
#  [510,
#   311,
#   11,
#   78,
#   20,
#   28,
#   391,
#   114,
#   1074,
#   69,
#   77,
#   374,
#   83,
#   557,
#   155,
#   1075,
#   1925,
#   49,
#   145,
#   21,
#   329,
#   17,
#   203,
#   3,
#   18,
#   231,
#   442],
#  [38,
#   28,
#   29,
#   369,
#   11,
#   7,
#   87,
#   1076,
#   145,
#   66,
#   335,
#   297,
#   76,
#   116,
#   377,
#   231,
#   1926],
#  [1077,
#   84,
#   135,
#   185,
#   746,
#   781,
#   100,
#   1078,
#   91,
#   443,
#   84,
#   101,
#   10,
#   25,
#   58,
#   46,
#   677,
#   1358,
#   270,
#   64,
#   270,
#   444,
#   31,
#   5,
#   1358,
#   43,
#   56,
#   180,
#   58,
#   14,
#   1927,
#   43,
#   4,
#   228,
#   140,
#   82,
#   84,
#   74,
#   1079,
#   1928,
#   17,
#   297,
#   4,
#   84,
#   74,
#   4,
#   101,
#   34,
#   74,
#   4,
#   84,
#   877,
#   112,
#   7,
#   687,
#   759,
#   294,
#   4,
#   5],
#  [3, 482, 985, 173],
#  [136,
#   1359,
#   8,
#   17,
#   3,
#   63,
#   8,
#   118,
#   6,
#   139,
#   154,
#   441,
#   121,
#   185,
#   782,
#   197,
#   311,
#   1360,
#   2,
#   367,
#   118,
#   6,
#   32,
#   1080,
#   235,
#   179,
#   311,
#   106,
#   303,
#   3,
#   17],
#  [1, 34, 2, 13, 153, 537, 7, 22, 6, 163, 19, 420, 259],
#  [],
#  [1, 95, 129, 44],
#  [20,
#   4,
#   58,
#   209,
#   194,
#   43,
#   3,
#   28,
#   87,
#   22,
#   104,
#   62,
#   22,
#   45,
#   50,
#   331,
#   178,
#   104,
#   1,
#   4,
#   236,
#   22,
#   891,
#   123,
#   52,
#   142,
#   1361,
#   76],
#  [],
#  [892, 3, 17],
#  [5, 3, 7, 1081, 398, 206],
#  [41, 8, 38, 6, 127, 9, 115, 16],
#  [3, 148, 19, 65, 155, 105, 26, 370, 1, 372, 15, 447, 119, 783, 1362],
#  [383,
#   384,
#   1929,
#   1351,
#   172,
#   1930,
#   688,
#   616,
#   254,
#   211,
#   1931,
#   196,
#   103,
#   421,
#   150,
#   327,
#   5,
#   3],
#  [15, 46, 35, 1363],
#  [186,
#   2,
#   26,
#   8,
#   156,
#   111,
#   12,
#   870,
#   549,
#   453,
#   674,
#   139,
#   9,
#   312,
#   148,
#   124,
#   33,
#   39,
#   3,
#   72,
#   2,
#   48,
#   28,
#   29,
#   501,
#   102],
#  [3, 17, 11, 7],
#  [147, 364],
#  [335],
#  [135, 115, 133, 34, 463, 18, 1082, 11, 7],
#  [107, 689, 30],
#  [14,
#   250,
#   491,
#   250,
#   491,
#   1083,
#   4,
#   82,
#   51,
#   403,
#   1932,
#   80,
#   1364,
#   1365,
#   1933,
#   214,
#   1934,
#   25,
#   51,
#   228,
#   4,
#   268,
#   1935,
#   30,
#   61,
#   25,
#   70,
#   4,
#   190],
#  [93, 461, 171, 41, 315, 617, 170, 1366, 1084, 188, 267, 232, 53, 145, 1085],
#  [3, 17, 246, 14, 19, 511, 375, 14],
#  [],
#  [],
#  [1936, 105, 19, 138, 1937, 1938],
#  [3, 17, 8, 294, 94],
#  [3, 110, 247, 470, 319, 50, 45, 35, 215],
#  [38, 784],
#  [133,
#   65,
#   528,
#   305,
#   24,
#   53,
#   302,
#   1086,
#   75,
#   653,
#   45,
#   1052,
#   1367,
#   214,
#   160,
#   437,
#   52,
#   121,
#   251],
#  [93, 2, 13, 275, 680, 29, 304, 531, 690, 36, 9, 2, 225, 95, 129, 334],
#  [1,
#   10,
#   3,
#   3,
#   43,
#   57,
#   691,
#   16,
#   15,
#   185,
#   158,
#   136,
#   42,
#   49,
#   8,
#   118,
#   237,
#   52,
#   167,
#   22,
#   6,
#   180,
#   16,
#   467,
#   27,
#   750,
#   469,
#   1010,
#   861,
#   18,
#   1,
#   3,
#   60,
#   25,
#   60],
#  [1, 4],
#  [144, 61, 331],
#  [5, 3, 15, 16, 6, 42, 19, 119, 15],
#  [1, 91, 313, 785],
#  [204,
#   24,
#   53,
#   4,
#   53,
#   558,
#   1,
#   6,
#   121,
#   21,
#   88,
#   512,
#   189,
#   313,
#   298,
#   893,
#   344,
#   126,
#   540,
#   126,
#   1,
#   738,
#   1087,
#   1368,
#   78,
#   21,
#   894,
#   3,
#   446,
#   59,
#   869,
#   9,
#   16,
#   1369,
#   1370,
#   1371,
#   770,
#   120,
#   2,
#   112,
#   1372,
#   114,
#   131,
#   769,
#   268,
#   19,
#   23,
#   114,
#   1373],
#  [1939, 175, 367, 128, 692, 776, 104],
#  [2,
#   48,
#   3,
#   11,
#   14,
#   224,
#   67,
#   852,
#   4,
#   10,
#   1940,
#   1941,
#   79,
#   320,
#   1942,
#   1943,
#   11,
#   27,
#   895,
#   4,
#   267,
#   398,
#   180,
#   645,
#   148,
#   152,
#   2,
#   48],
#  [92, 13, 1088, 35, 71],
#  [243, 8, 136, 592, 23, 40, 131, 1944],
#  [4,
#   209,
#   726,
#   5,
#   1945,
#   313,
#   1089,
#   189,
#   260,
#   62,
#   48,
#   19,
#   30,
#   23,
#   10,
#   45,
#   308,
#   26,
#   307,
#   685,
#   601,
#   96,
#   116,
#   76,
#   786,
#   52,
#   116,
#   896,
#   58,
#   192,
#   32,
#   21,
#   378],
#  [3, 9, 574, 77, 79],
#  [353, 17],
#  [81, 618],
#  [11, 7],
#  [8, 4, 10, 116],
#  [116,
#   103,
#   444,
#   1374,
#   20,
#   693,
#   1090,
#   448,
#   558,
#   1091,
#   106,
#   1946,
#   19,
#   338,
#   426,
#   406,
#   849,
#   162,
#   694,
#   695,
#   1092,
#   19,
#   18,
#   108,
#   12,
#   167,
#   1947,
#   7,
#   171,
#   8,
#   31,
#   449,
#   228,
#   12,
#   996,
#   1948,
#   1949,
#   4,
#   34,
#   95,
#   244,
#   418,
#   92,
#   1950,
#   725,
#   4,
#   886,
#   619,
#   21,
#   506],
#  [453,
#   20,
#   433,
#   90,
#   559,
#   2,
#   890,
#   239,
#   156,
#   692,
#   1,
#   183,
#   1,
#   1,
#   318,
#   52,
#   381,
#   104,
#   52,
#   612,
#   49,
#   274,
#   8,
#   1059,
#   162,
#   135,
#   211,
#   407,
#   25,
#   897,
#   46,
#   71,
#   71,
#   45,
#   1375,
#   427,
#   1376,
#   604,
#   898],
#  [1, 1093, 681, 149, 141],
#  [454, 1259, 332, 21],
#  [8],
#  [1, 18, 22, 171],
#  [1, 2, 13, 1951],
#  [2, 10, 11, 14, 5, 212],
#  [38,
#   28,
#   29,
#   1094,
#   487,
#   435,
#   498,
#   15,
#   56,
#   69,
#   202,
#   2,
#   48,
#   416,
#   1377,
#   21,
#   395,
#   696,
#   42,
#   357,
#   1095,
#   899,
#   1952,
#   316,
#   900,
#   193,
#   22,
#   340,
#   260,
#   506,
#   1953,
#   104,
#   560,
#   80,
#   1954,
#   507,
#   237,
#   6,
#   237,
#   1955,
#   250,
#   207,
#   75,
#   269,
#   392,
#   1956,
#   24,
#   146,
#   10,
#   78,
#   13,
#   316,
#   1096,
#   2,
#   48,
#   94,
#   436,
#   15],
#  [44, 177, 150, 86, 561, 9, 901, 1097, 26, 75, 281, 303, 196, 697, 225],
#  [11, 7],
#  [1],
#  [65,
#   321,
#   461,
#   643,
#   155,
#   733,
#   5,
#   16,
#   471,
#   678,
#   894,
#   21,
#   4,
#   33,
#   872,
#   8,
#   872,
#   4,
#   25,
#   54,
#   872,
#   562,
#   47,
#   5,
#   109,
#   182,
#   117,
#   6,
#   20,
#   340,
#   313,
#   1957,
#   178,
#   104,
#   1958,
#   787],
#  [24,
#   42,
#   5,
#   79,
#   9,
#   1959,
#   388,
#   2,
#   42,
#   30,
#   67,
#   19,
#   388,
#   2,
#   9,
#   593,
#   33,
#   387,
#   155,
#   1960,
#   698,
#   1378,
#   19,
#   255,
#   1098,
#   9,
#   256],
#  [150, 159, 33, 1099, 2, 48, 6, 173, 23, 12, 39],
#  [1365, 1060, 1379, 620, 1380, 1961, 1962],
#  [54,
#   37,
#   1381,
#   699,
#   202,
#   44,
#   372,
#   428,
#   902,
#   648,
#   23,
#   85,
#   557,
#   1,
#   2,
#   258,
#   903,
#   1100,
#   1382,
#   23,
#   700,
#   429,
#   10,
#   694,
#   563,
#   12,
#   1383,
#   1384,
#   1385,
#   788,
#   403,
#   82,
#   1386,
#   296,
#   1101,
#   1387,
#   904,
#   1388,
#   789,
#   82,
#   1389,
#   16,
#   18,
#   131,
#   659,
#   10,
#   5,
#   658,
#   4,
#   67,
#   82,
#   20,
#   85,
#   494,
#   10,
#   621,
#   173,
#   1390],
#  [146, 386, 54],
#  [97, 3],
#  [8,
#   51,
#   19,
#   59,
#   173,
#   426,
#   45,
#   122,
#   6,
#   468,
#   15,
#   256,
#   188,
#   8,
#   1391,
#   29,
#   275,
#   468,
#   513,
#   104,
#   674,
#   309,
#   29,
#   277,
#   2,
#   22,
#   6,
#   787,
#   1963,
#   513,
#   104,
#   2,
#   468,
#   790,
#   104,
#   787,
#   275,
#   468,
#   674,
#   29,
#   65,
#   1964],
#  [20,
#   2,
#   10,
#   93,
#   143,
#   353,
#   21,
#   170,
#   105,
#   68,
#   326,
#   34,
#   72,
#   1102,
#   2,
#   209,
#   174,
#   166,
#   154,
#   22,
#   6,
#   174,
#   1103,
#   1965,
#   55,
#   27,
#   33],
#  [116, 1392, 58, 696],
#  [214, 182, 299, 118, 6, 236, 40, 842, 97, 232, 290, 30, 17, 23],
#  [1, 1393, 358, 242, 372, 30, 672, 1394],
#  [1, 149, 141, 11, 7],
#  [1395,
#   1396,
#   1397,
#   701,
#   1398,
#   905,
#   1399,
#   1400,
#   1401,
#   1402,
#   1403,
#   1104,
#   1404,
#   1405,
#   1406,
#   1407],
#  [353, 11, 84, 3, 17, 347, 152],
#  [1, 51, 231, 381, 178, 104],
#  [3,
#   40,
#   457,
#   21,
#   79,
#   64,
#   32,
#   19,
#   1105,
#   229,
#   123,
#   192,
#   55,
#   885,
#   336,
#   32,
#   1966,
#   202,
#   155,
#   31,
#   25,
#   8,
#   52,
#   145,
#   408,
#   409,
#   24,
#   26,
#   305,
#   1408,
#   467,
#   72],
#  [93,
#   28,
#   29,
#   431,
#   906,
#   234,
#   2,
#   48,
#   113,
#   486,
#   1967,
#   551,
#   1011,
#   1968,
#   120,
#   242,
#   486,
#   1969,
#   1106,
#   114,
#   175,
#   1970,
#   32,
#   371,
#   791,
#   49,
#   546,
#   676,
#   54,
#   370,
#   295,
#   123,
#   142,
#   1971,
#   75,
#   3,
#   89,
#   88,
#   6,
#   123,
#   553,
#   237,
#   52,
#   120,
#   45,
#   1972,
#   318,
#   1973,
#   792,
#   18,
#   907,
#   312,
#   12,
#   25,
#   92,
#   25,
#   148,
#   152],
#  [18, 89, 133, 19, 12, 62, 133],
#  [8, 243, 47],
#  [4, 107, 1974, 27, 1409, 66, 174, 42, 111, 616, 27, 1409, 5, 1107, 207],
#  [1,
#   449,
#   1975,
#   6,
#   196,
#   1976,
#   1410,
#   11,
#   101,
#   908,
#   189,
#   9,
#   16,
#   367,
#   77,
#   79,
#   19,
#   61,
#   121],
#  [5, 3],
#  [256, 76, 3, 378],
#  [863, 145, 785],
#  [793, 42, 54],
#  [11, 510, 14, 35, 9, 2, 13, 30, 15, 1411, 73],
#  [702,
#   358,
#   2,
#   13,
#   1977,
#   702,
#   703,
#   1108,
#   3,
#   164,
#   22,
#   52,
#   6,
#   265,
#   578,
#   15,
#   115,
#   255],
#  [16, 9, 5, 37],
#  [83, 1978],
#  [3],
#  [8, 410, 161, 1979, 79, 246, 186, 2],
#  [92, 1980, 1981, 181, 25, 131, 25, 5, 8, 135, 25],
#  [143, 110, 112, 1107, 1109, 2, 14, 39, 249, 1110, 1982],
#  [],
#  [2, 156, 192, 410, 111, 39, 5, 909, 3],
#  [1, 33],
#  [5, 3, 38, 129, 1983, 11, 40, 7],
#  [1],
#  [44, 1, 4, 47, 205, 56],
#  [17,
#   27,
#   1984,
#   161,
#   439,
#   1985,
#   1986,
#   448,
#   213,
#   282,
#   1987,
#   351,
#   213,
#   333,
#   17,
#   1111],
#  [],
#  [1, 250, 491, 35, 463, 10, 1112, 69, 98, 93, 577, 93],
#  [1, 4, 390, 33, 7],
#  [8, 1988, 910, 1412, 1989, 20],
#  [911, 393, 21, 8, 1990, 1991, 6],
#  [],
#  [1992, 18, 318, 142, 239, 1260, 896, 76, 3, 1993, 550],
#  [177, 12, 5, 37],
#  [537, 7, 6, 53, 21, 26, 274, 312, 54],
#  [],
#  [993, 5, 301, 21, 354, 54, 209, 330, 5, 112],
#  [1, 4, 374, 11, 7],
#  [912,
#   188,
#   20,
#   2,
#   510,
#   11,
#   70,
#   4,
#   82,
#   93,
#   564,
#   30,
#   157,
#   85,
#   216,
#   39,
#   27,
#   510,
#   11,
#   70,
#   564,
#   82,
#   1413,
#   153,
#   2,
#   188,
#   118,
#   6,
#   2,
#   9,
#   36,
#   107,
#   247,
#   564,
#   30,
#   74,
#   113,
#   84,
#   1113,
#   267,
#   232,
#   290,
#   622,
#   23],
#  [149, 141, 83, 11, 84, 11, 7, 107, 191, 28, 29],
#  [1],
#  [8,
#   2,
#   48,
#   224,
#   67,
#   5,
#   1994,
#   686,
#   10,
#   20,
#   50,
#   3,
#   17,
#   1304,
#   106,
#   12,
#   10,
#   2,
#   13,
#   120],
#  [1, 10],
#  [472,
#   224,
#   366,
#   5,
#   37,
#   913,
#   153,
#   309,
#   122,
#   6,
#   468,
#   1414,
#   371,
#   131,
#   2,
#   13,
#   164,
#   28,
#   29,
#   207,
#   657,
#   112,
#   6,
#   22,
#   103,
#   26,
#   8,
#   119,
#   94,
#   459,
#   15,
#   36,
#   9],
#  [81,
#   16,
#   21,
#   4,
#   1415,
#   192,
#   64,
#   1995,
#   103,
#   30,
#   23,
#   841,
#   19,
#   1018,
#   62,
#   121,
#   18,
#   121,
#   192,
#   27,
#   82,
#   42,
#   54,
#   27,
#   2,
#   48,
#   103,
#   30,
#   67,
#   46,
#   7,
#   35,
#   250,
#   529,
#   37,
#   199,
#   1114,
#   16,
#   443,
#   441,
#   23,
#   30],
#  [72,
#   17,
#   58,
#   36,
#   58,
#   49,
#   148,
#   317,
#   185,
#   339,
#   136,
#   2,
#   13,
#   135,
#   114,
#   254,
#   873,
#   514,
#   90,
#   66,
#   17,
#   327,
#   21,
#   5,
#   26,
#   8,
#   352,
#   423,
#   10,
#   31,
#   15,
#   255,
#   322,
#   119,
#   15,
#   1416,
#   130,
#   2,
#   13,
#   87,
#   287,
#   437,
#   7,
#   1115,
#   373,
#   179,
#   8,
#   997,
#   10,
#   48,
#   139,
#   1116,
#   25,
#   148,
#   623,
#   151,
#   60,
#   1117,
#   12,
#   282,
#   4],
#  [],
#  [1, 22, 6, 726, 77, 704, 50, 11],
#  [3, 10, 452, 1996, 139],
#  [1, 27, 74, 49],
#  [98, 565, 911, 35, 157, 110],
#  [3, 17, 197, 4, 210, 79, 149, 64, 1296, 15],
#  [1],
#  [3, 72, 5, 212, 1094, 151, 1417, 25, 60],
#  [95, 18, 1248, 215, 33],
#  [11, 84, 197, 1997, 5, 1118, 311, 149, 141, 165, 89, 1998, 391],
#  [1999,
#   20,
#   28,
#   90,
#   149,
#   64,
#   141,
#   93,
#   12,
#   211,
#   21,
#   610,
#   98,
#   38,
#   20,
#   28,
#   29,
#   705,
#   508,
#   4,
#   49],
#  [1418, 132],
#  [52, 121, 396],
#  [24,
#   615,
#   94,
#   10,
#   432,
#   54,
#   224,
#   67,
#   38,
#   489,
#   94,
#   10,
#   515,
#   47,
#   25,
#   511,
#   10,
#   24,
#   775,
#   447,
#   2,
#   48,
#   267,
#   232,
#   49,
#   51,
#   22,
#   6,
#   402,
#   59,
#   120,
#   112],
#  [299, 7],
#  [5],
#  [393, 411, 17, 329, 228, 1419, 624, 215, 20],
#  [525, 129, 214, 1420, 2, 1],
#  [5,
#   3,
#   405,
#   57,
#   683,
#   4,
#   5,
#   37,
#   1421,
#   2,
#   197,
#   4,
#   122,
#   131,
#   2000,
#   158,
#   34,
#   213,
#   15,
#   31,
#   16,
#   1421,
#   2,
#   76,
#   116,
#   26,
#   308,
#   1093,
#   494,
#   52,
#   527,
#   536,
#   394,
#   3,
#   405],
#  [1, 4],
#  [466, 2, 2, 32],
#  [263, 77, 2],
#  [26, 11, 7],
#  [11, 7],
#  [280, 211, 80, 2, 19, 182, 6, 1422, 229, 4, 114, 744, 1, 2, 1, 4],
#  [116, 15, 1119, 9, 3, 16, 119, 15],
#  [16, 223, 116, 706, 166, 986, 625, 59, 618],
#  [1,
#   137,
#   2,
#   71,
#   914,
#   440,
#   240,
#   2,
#   32,
#   8,
#   114,
#   266,
#   2001,
#   2002,
#   1120,
#   389,
#   9,
#   1423,
#   612,
#   2003,
#   49,
#   3,
#   116,
#   176,
#   124,
#   1121,
#   1,
#   4,
#   17,
#   276,
#   99,
#   304],
#  [18, 3, 16, 9, 47, 109, 670, 27, 7, 37],
#  [3, 17],
#  [626, 2004],
#  [41, 308, 184, 171, 89, 7, 4],
#  [69, 781, 108],
#  [1],
#  [5, 602, 31, 16, 9, 36, 589, 72, 285, 49],
#  [4,
#   13,
#   21,
#   26,
#   188,
#   4,
#   32,
#   3,
#   1122,
#   1123,
#   104,
#   59,
#   468,
#   2005,
#   16,
#   171,
#   915,
#   12,
#   318,
#   1,
#   343,
#   2006,
#   142,
#   360,
#   211,
#   176,
#   131,
#   47],
#  [422,
#   11,
#   220,
#   6,
#   319,
#   88,
#   20,
#   6,
#   470,
#   1098,
#   2007,
#   387,
#   9,
#   1,
#   246,
#   124,
#   651,
#   56,
#   157,
#   58,
#   27,
#   1255,
#   16,
#   2008,
#   384],
#  [15, 35, 225, 2],
#  [1, 13, 11, 7, 102, 48, 2, 71, 12, 178, 49, 314, 88, 6, 20, 1089, 189, 340],
#  [1, 134, 47, 360],
#  [5, 3],
#  [4,
#   3,
#   504,
#   159,
#   601,
#   1424,
#   600,
#   586,
#   163,
#   229,
#   2009,
#   70,
#   4,
#   460,
#   2010,
#   12,
#   707,
#   2,
#   13,
#   707,
#   1022,
#   1425,
#   794,
#   349,
#   794,
#   349,
#   373,
#   1046,
#   179,
#   1045],
#  [5, 37, 42, 379, 538, 455, 79, 16, 1036, 9, 691, 37],
#  [1, 2011, 60, 16, 69, 618, 34, 273, 1426, 34, 916, 12, 81, 1427, 1124, 3, 60],
#  [177, 261, 315, 299, 7],
#  [5],
#  [8, 65, 71, 917, 39, 4, 724],
#  [41, 16, 5, 3],
#  [5, 16, 181, 63, 96, 54, 66, 135, 516, 66, 47],
#  [26, 1, 67, 49],
#  [11, 7, 84],
#  [918, 482, 182, 99],
#  [1],
#  [41,
#   115,
#   134,
#   71,
#   26,
#   1428,
#   43,
#   66,
#   46,
#   192,
#   708,
#   756,
#   993,
#   8,
#   231,
#   335,
#   1429,
#   106,
#   1125,
#   12,
#   50,
#   367,
#   41,
#   16],
#  [1,
#   162,
#   425,
#   2,
#   13,
#   19,
#   6,
#   23,
#   837,
#   100,
#   285,
#   1341,
#   19,
#   111,
#   71,
#   86,
#   1,
#   43,
#   59,
#   9,
#   77],
#  [7, 17, 919, 1],
#  [840, 657, 47, 566, 301, 90, 21, 427, 124, 265, 131, 158, 795, 920],
#  [58, 17],
#  [11, 84, 1, 18],
#  [28,
#   29,
#   341,
#   2,
#   285,
#   46,
#   796,
#   461,
#   30,
#   23,
#   14,
#   46,
#   517,
#   54,
#   4,
#   259,
#   83,
#   420,
#   473,
#   30,
#   10,
#   400,
#   85,
#   27,
#   30,
#   157,
#   64,
#   120,
#   321,
#   473,
#   2,
#   165,
#   61,
#   82,
#   5,
#   212,
#   112,
#   365,
#   159,
#   140,
#   584,
#   30,
#   10,
#   154,
#   33,
#   9,
#   36,
#   16,
#   176,
#   164,
#   1002,
#   4,
#   122,
#   77,
#   45,
#   318,
#   142,
#   497,
#   125,
#   599,
#   3,
#   1430,
#   148,
#   159,
#   58,
#   328,
#   23,
#   263,
#   598,
#   8,
#   285,
#   303,
#   3,
#   223,
#   23,
#   1126,
#   91,
#   1086,
#   190,
#   130,
#   159,
#   4,
#   23],
#  [44,
#   2,
#   71,
#   28,
#   29,
#   1,
#   92,
#   24,
#   65,
#   749,
#   772,
#   623,
#   1431,
#   60,
#   614,
#   7,
#   189,
#   43,
#   57,
#   155,
#   189,
#   313,
#   25,
#   197,
#   172,
#   538,
#   31,
#   8,
#   266,
#   9,
#   140,
#   690,
#   59,
#   24,
#   797,
#   140,
#   775,
#   136,
#   592,
#   9,
#   4,
#   2012,
#   40],
#  [1127,
#   60,
#   2,
#   2,
#   13,
#   179,
#   16,
#   176,
#   2,
#   471,
#   9,
#   36,
#   26,
#   253,
#   337,
#   249,
#   369,
#   44,
#   281,
#   9,
#   26,
#   41,
#   1432,
#   2,
#   13,
#   88,
#   1118,
#   2013,
#   65,
#   383],
#  [58],
#  [117, 6, 627, 789, 518, 21, 267, 59, 91, 709, 171, 168, 14],
#  [5, 3, 487, 628, 39],
#  [66,
#   301,
#   18,
#   277,
#   105,
#   519,
#   1433,
#   165,
#   1128,
#   45,
#   127,
#   17,
#   864,
#   54,
#   686,
#   105,
#   208,
#   263,
#   165,
#   366,
#   139,
#   1434,
#   165,
#   733,
#   376,
#   6,
#   921,
#   20,
#   6],
#  [],
#  [268, 1],
#  [1],
#  [58, 17],
#  [238, 18],
#  [215,
#   1435,
#   43,
#   57,
#   2014,
#   19,
#   2015,
#   176,
#   266,
#   27,
#   621,
#   2016,
#   1129,
#   2017,
#   548,
#   2018,
#   258,
#   474,
#   39,
#   682,
#   4,
#   49,
#   58,
#   117,
#   6,
#   163,
#   3,
#   182,
#   1436,
#   922,
#   1130,
#   512,
#   127,
#   7,
#   140,
#   1131,
#   19,
#   512,
#   8,
#   52,
#   735,
#   2019,
#   485,
#   137,
#   109,
#   316,
#   36,
#   33,
#   35,
#   2,
#   13],
#  [798,
#   380,
#   23,
#   3,
#   21,
#   6,
#   201,
#   777,
#   839,
#   254,
#   621,
#   117,
#   145,
#   263,
#   330,
#   1437,
#   79,
#   4,
#   264,
#   65,
#   421,
#   502,
#   548,
#   222,
#   25,
#   31,
#   16,
#   18],
#  [15, 9, 16],
#  [43, 474, 21, 552, 1238],
#  [5, 3, 15, 9, 112, 303, 25, 152],
#  [42, 923, 923, 1438],
#  [83],
#  [133, 65, 15, 1, 43, 144, 15, 9, 3],
#  [4,
#   51,
#   121,
#   61,
#   101,
#   31,
#   530,
#   27,
#   2020,
#   217,
#   23,
#   29,
#   520,
#   55,
#   27,
#   25,
#   882,
#   297,
#   10,
#   101,
#   61,
#   108,
#   75,
#   1,
#   560,
#   6],
#  [1],
#  [11, 510, 14, 35, 9, 2, 13, 30, 15, 1411, 73],
#  [24, 78, 69, 4, 144, 64, 190, 18, 153, 7, 6, 173, 3],
#  [863,
#   255,
#   487,
#   39,
#   497,
#   67,
#   200,
#   5,
#   1439,
#   2021,
#   751,
#   124,
#   77,
#   79,
#   2022,
#   60,
#   164,
#   67,
#   5,
#   1439,
#   31,
#   9,
#   1440,
#   89,
#   85,
#   2023,
#   130,
#   924,
#   13,
#   151,
#   60,
#   2,
#   13,
#   2,
#   225,
#   2,
#   13,
#   124,
#   77,
#   79,
#   30,
#   18,
#   67,
#   100,
#   278,
#   316,
#   256,
#   13,
#   31,
#   179,
#   122,
#   77,
#   35,
#   243,
#   1132],
#  [15, 1441, 36, 134, 73],
#  [76, 683, 15, 4, 203, 748, 2024, 2, 32, 703, 867],
#  [199, 128, 999],
#  [40, 1003, 401, 1442, 145, 799, 96, 2025, 4, 145, 133, 2026],
#  [],
#  [382, 246, 8, 314, 163],
#  [43, 6, 173, 59],
#  [3, 9, 574, 77, 79],
#  [47, 109],
#  [3, 17, 3, 72, 28, 29, 400, 4],
#  [297,
#   1443,
#   342,
#   217,
#   603,
#   71,
#   396,
#   102,
#   18,
#   19,
#   2027,
#   26,
#   426,
#   184,
#   925,
#   414,
#   554,
#   2028,
#   68,
#   4,
#   252,
#   154,
#   42,
#   14,
#   1444,
#   71,
#   525,
#   2029,
#   342,
#   1443,
#   80,
#   282,
#   1445,
#   407,
#   1133,
#   91,
#   107,
#   49,
#   4,
#   2030,
#   470,
#   559,
#   1134,
#   231,
#   319,
#   763,
#   24,
#   329,
#   75,
#   233,
#   71,
#   926,
#   1446,
#   156,
#   73,
#   32,
#   295,
#   24,
#   475,
#   249,
#   2031,
#   1,
#   1287,
#   65,
#   2032],
#  [7,
#   17,
#   43,
#   57,
#   1,
#   51,
#   14,
#   554,
#   204,
#   1447,
#   1120,
#   1300,
#   1448,
#   65,
#   184,
#   914,
#   2033],
#  [299, 7, 91, 709, 1084],
#  [2, 241, 24, 53, 7, 6, 332, 871, 506],
#  [147, 3, 224, 67, 5, 3],
#  [11, 14, 11, 7],
#  [798,
#   380,
#   23,
#   3,
#   21,
#   6,
#   201,
#   777,
#   839,
#   254,
#   621,
#   117,
#   145,
#   263,
#   330,
#   1437,
#   79,
#   4,
#   264,
#   65,
#   421,
#   502,
#   548,
#   222,
#   25,
#   31,
#   16,
#   18],
#  [563, 563, 9],
#  [26, 1, 20, 2, 92, 9, 36, 3, 87, 40, 26, 376, 6, 19, 219, 59, 1449],
#  [130, 1],
#  [376, 113, 14, 154, 158, 424, 138, 139, 2034, 1450],
#  [386, 156, 1451, 800, 215, 33],
#  [69, 356, 230, 80, 103],
#  [549,
#   337,
#   436,
#   383,
#   578,
#   272,
#   1452,
#   149,
#   141,
#   135,
#   389,
#   475,
#   408,
#   2035,
#   10,
#   2036,
#   327,
#   64,
#   249,
#   164,
#   70,
#   20,
#   149,
#   141,
#   476,
#   128,
#   884,
#   25,
#   148,
#   152,
#   17],
#  [2, 13, 382, 174, 45, 201, 927, 253, 8, 983, 174],
#  [234,
#   89,
#   220,
#   2,
#   1453,
#   28,
#   310,
#   92,
#   181,
#   288,
#   475,
#   52,
#   6,
#   120,
#   31,
#   92,
#   84,
#   82,
#   1454,
#   629,
#   6,
#   8,
#   37,
#   895,
#   2,
#   333,
#   63,
#   331,
#   2,
#   130,
#   45,
#   127,
#   14,
#   22,
#   126,
#   139,
#   31,
#   8,
#   193,
#   283,
#   790,
#   1455,
#   331,
#   330,
#   161,
#   8,
#   404,
#   1456,
#   2,
#   354,
#   1457],
#  [8, 89, 123, 200, 47, 280, 32, 42, 270, 2037],
#  [38, 100, 2038, 39, 105, 68, 143, 97, 16, 5, 8, 34],
#  [],
#  [116, 15, 1119, 9, 3, 16, 119, 15],
#  [1135],
#  [2, 13, 1136, 10, 95, 18, 172, 211, 21],
#  [76,
#   338,
#   21,
#   89,
#   35,
#   109,
#   9,
#   36,
#   16,
#   31,
#   1344,
#   55,
#   76,
#   145,
#   13,
#   111,
#   39,
#   334,
#   657,
#   35,
#   12,
#   382],
#  [5, 3, 161, 106],
#  [5, 3, 2039, 30, 23, 84],
#  [3, 9, 574, 79],
#  [34, 95, 244],
#  [573,
#   151,
#   2,
#   225,
#   26,
#   19,
#   200,
#   52,
#   361,
#   10,
#   25,
#   897,
#   1375,
#   630,
#   378,
#   262,
#   2040,
#   801,
#   141,
#   90,
#   710,
#   1458,
#   1459,
#   45,
#   631,
#   802,
#   729,
#   2041,
#   101,
#   743,
#   31,
#   103,
#   10,
#   2042,
#   103,
#   2,
#   10,
#   72,
#   281,
#   199],
#  [349, 116, 10, 72, 16, 9, 83, 273, 49, 23],
#  [375],
#  [15, 9, 16],
#  [8, 2043, 899, 136, 592, 264, 23],
#  [8, 243, 47],
#  [1, 113, 5, 37],
#  [3, 9, 137, 1460, 632, 4],
#  [1021, 1338, 4],
#  [346, 24, 53],
#  [10, 2044, 51, 286, 711, 2045, 61, 167, 105, 19, 5],
#  [11, 84, 1],
#  [18, 3, 198, 20, 28],
#  [2,
#   71,
#   5,
#   37,
#   471,
#   5,
#   235,
#   712,
#   751,
#   788,
#   164,
#   1461,
#   874,
#   135,
#   25,
#   82,
#   404,
#   633,
#   928,
#   2046,
#   235,
#   219,
#   895],
#  [80,
#   2047,
#   7,
#   91,
#   49,
#   1062,
#   75,
#   7,
#   3,
#   43,
#   174,
#   1462,
#   243,
#   1463,
#   122,
#   43,
#   86,
#   216,
#   39,
#   185,
#   176,
#   166,
#   40,
#   63,
#   601,
#   96,
#   122,
#   338,
#   521,
#   2048,
#   1464,
#   190],
#  [9, 3, 52, 3, 42, 171, 47, 75, 52, 237, 88, 6, 123, 132],
#  [16],
#  [1, 4, 50, 40, 296, 205, 527, 90, 21],
#  [38, 268, 1],
#  [1, 2, 1, 118, 6, 39],
#  [117, 300, 189, 194, 713, 27, 120, 206, 218, 420, 195, 56, 9, 206, 463, 1465],
#  [268, 1],
#  [207,
#   17,
#   333,
#   228,
#   102,
#   170,
#   150,
#   731,
#   12,
#   2049,
#   2050,
#   248,
#   20,
#   2051,
#   2052,
#   82,
#   94,
#   2,
#   48,
#   198,
#   311,
#   333,
#   70,
#   929,
#   61,
#   758,
#   2053,
#   2054,
#   1466,
#   529,
#   929,
#   295,
#   930,
#   175,
#   20,
#   1427,
#   404,
#   28,
#   21],
#  [5, 3],
#  [4, 66, 169, 91, 96, 277, 629, 277, 91, 2055, 1467, 297, 1467, 899, 151],
#  [303, 8, 127, 567, 61, 42, 30, 23, 1468, 50, 12, 40, 7, 6, 231, 470, 319],
#  [1],
#  [11, 14, 1343, 1],
#  [24, 53, 89, 7, 406, 803, 452, 63, 22, 6, 1469, 1038, 689],
#  [1, 51, 4, 1297, 2056, 1132, 2057, 209],
#  [51, 159, 15, 48, 124, 931, 547, 1, 196, 472, 86],
#  [262, 64, 3, 378, 97, 8, 34, 64],
#  [1, 71],
#  [5, 3, 35, 702, 149, 141],
#  [395, 36, 9, 2, 148, 932, 459, 477, 339, 136, 7, 392, 6, 310],
#  [1, 34, 2, 158, 248, 6, 138, 478, 14, 138, 1470],
#  [3, 17, 72, 5, 37],
#  [1],
#  [24, 53, 7, 41, 2, 3, 9, 282, 33, 35, 561],
#  [3, 6, 65, 377, 278, 5],
#  [202,
#   155,
#   396,
#   1,
#   123,
#   2058,
#   435,
#   2059,
#   12,
#   98,
#   46,
#   123,
#   2060,
#   2061,
#   80,
#   359,
#   1137,
#   2062,
#   160,
#   287,
#   497,
#   138,
#   174,
#   280,
#   211,
#   1249,
#   2063,
#   2064,
#   2065],
#  [58,
#   378,
#   16,
#   9,
#   2066,
#   621,
#   13,
#   13,
#   122,
#   603,
#   56,
#   32,
#   297,
#   1,
#   32,
#   123,
#   64,
#   142,
#   2067,
#   2068,
#   113,
#   132,
#   118,
#   6,
#   1],
#  [531,
#   1471,
#   544,
#   105,
#   123,
#   200,
#   80,
#   2069,
#   93,
#   28,
#   29,
#   48,
#   69,
#   2070,
#   359,
#   804,
#   357,
#   309,
#   274,
#   357,
#   195,
#   72,
#   503,
#   62,
#   151,
#   175,
#   542,
#   184,
#   7,
#   439,
#   175,
#   155,
#   463,
#   10,
#   66,
#   198,
#   350,
#   106,
#   103,
#   10,
#   507],
#  [1,
#   4,
#   7,
#   22,
#   6,
#   22,
#   189,
#   1472,
#   22,
#   512,
#   1131,
#   14,
#   252,
#   88,
#   408,
#   409,
#   132,
#   59,
#   128,
#   194,
#   1473,
#   865,
#   126,
#   8,
#   51,
#   77,
#   85,
#   125,
#   130,
#   568,
#   101,
#   34,
#   239,
#   457,
#   4,
#   210,
#   488],
#  [11, 84, 70, 82, 31, 11, 228, 61, 9, 36, 117, 6, 340, 241],
#  [8],
#  [108],
#  [133, 65, 15, 1, 43, 144, 15, 9, 3],
#  [5, 37, 11, 14],
#  [5, 3, 38, 1138, 8, 450, 56],
#  [40],
#  [2071],
#  [4,
#   745,
#   15,
#   42,
#   419,
#   18,
#   2072,
#   169,
#   96,
#   277,
#   54,
#   2073,
#   66,
#   47,
#   233,
#   624,
#   175,
#   70,
#   61,
#   105,
#   26,
#   97,
#   200,
#   115,
#   33,
#   414,
#   50,
#   40,
#   1474,
#   151,
#   107,
#   459,
#   119,
#   160,
#   38,
#   784,
#   203,
#   423,
#   304,
#   87,
#   134,
#   195,
#   56,
#   183,
#   323,
#   395,
#   161,
#   152,
#   495,
#   471,
#   2074,
#   2075,
#   1,
#   423,
#   42,
#   51,
#   1239,
#   138,
#   625,
#   714],
#  [1,
#   1,
#   34,
#   65,
#   539,
#   162,
#   203,
#   33,
#   238,
#   8,
#   375,
#   1475,
#   216,
#   23,
#   1139,
#   42,
#   2076,
#   933,
#   164,
#   4,
#   22,
#   47,
#   42,
#   114,
#   19,
#   4,
#   13,
#   346,
#   39,
#   400],
#  [207, 4, 122, 354, 332],
#  [1,
#   17,
#   264,
#   2077,
#   47,
#   77,
#   1032,
#   7,
#   166,
#   328,
#   251,
#   203,
#   2078,
#   469,
#   8,
#   216,
#   2079,
#   394],
#  [5, 35, 135],
#  [134,
#   71,
#   448,
#   1033,
#   21,
#   179,
#   666,
#   801,
#   1476,
#   288,
#   122,
#   45,
#   201,
#   306,
#   24,
#   2080,
#   1477,
#   785],
#  [1, 101, 795, 30, 286, 157, 94],
#  [12, 448, 451, 204, 21, 781],
#  [5, 3, 934, 33, 35, 341, 10, 70, 25, 152, 341, 2081, 934, 2082],
#  [1, 8, 177, 214],
#  [1,
#   765,
#   1478,
#   260,
#   6,
#   3,
#   51,
#   14,
#   746,
#   29,
#   100,
#   80,
#   6,
#   23,
#   31,
#   185,
#   44,
#   166,
#   2083,
#   2084,
#   1458,
#   68,
#   4,
#   22,
#   2085,
#   6,
#   1410,
#   5,
#   1408,
#   87,
#   2086,
#   2087,
#   645,
#   394,
#   292,
#   1479,
#   221,
#   273],
#  [1],
#  [5, 3],
#  [51, 7, 4, 2, 3],
#  [9,
#   36,
#   16,
#   242,
#   72,
#   359,
#   25,
#   152,
#   19,
#   2,
#   13,
#   60,
#   35,
#   15,
#   397,
#   634,
#   522,
#   7,
#   2,
#   13],
#  [116, 269, 1140, 13, 1480, 4, 420, 106, 805, 109, 116, 15],
#  [11, 14],
#  [],
#  [18,
#   107,
#   44,
#   28,
#   29,
#   3,
#   191,
#   98,
#   93,
#   102,
#   31,
#   38,
#   2,
#   32,
#   715,
#   9,
#   935,
#   16,
#   2,
#   48,
#   2,
#   32,
#   217,
#   2088,
#   2089,
#   8,
#   76,
#   91,
#   49,
#   78,
#   850,
#   24,
#   199,
#   72],
#  [410,
#   1023,
#   54,
#   33,
#   698,
#   249,
#   24,
#   5,
#   37,
#   36,
#   9,
#   246,
#   1047,
#   11,
#   5,
#   4,
#   1124,
#   16,
#   77,
#   208],
#  [117, 300, 189, 194, 713, 27, 120, 206, 218, 420, 195, 56, 9, 206, 463, 1465],
#  [81,
#   254,
#   178,
#   4,
#   10,
#   41,
#   2090,
#   235,
#   180,
#   20,
#   806,
#   420,
#   26,
#   37,
#   1481,
#   2,
#   1482,
#   216,
#   39,
#   179,
#   2091,
#   16,
#   420,
#   20],
#  [179,
#   5,
#   37,
#   633,
#   87,
#   430,
#   1483,
#   91,
#   2092,
#   5,
#   167,
#   237,
#   103,
#   1283,
#   167,
#   217,
#   10,
#   556,
#   533,
#   220,
#   10,
#   8,
#   45,
#   2093,
#   30,
#   64,
#   2094,
#   93,
#   807,
#   655,
#   635,
#   75,
#   777,
#   636],
#  [1, 369, 44, 28, 29, 432, 25, 363, 359, 195, 72],
#  [410, 135, 25, 134, 44, 352, 936, 2095, 405, 2096],
#  [315, 2, 255, 122, 77, 210, 33, 35, 702, 715],
#  [69, 85, 30, 23, 10, 5, 3],
#  [1, 133, 18],
#  [8, 116, 24, 51, 75, 235, 180],
#  [298, 20, 2097, 370, 274, 187, 3, 2098, 17, 568, 637, 203],
#  [1,
#   4,
#   772,
#   159,
#   32,
#   23,
#   1484,
#   545,
#   32,
#   66,
#   357,
#   424,
#   2,
#   460,
#   86,
#   516,
#   359,
#   32,
#   247,
#   23,
#   2099,
#   63,
#   544],
#  [1, 32, 104, 799, 76, 118, 31, 21, 679, 132, 120],
#  [43, 711, 252],
#  [8, 51, 123, 115, 33, 200, 62, 2100, 5, 3],
#  [4,
#   115,
#   458,
#   243,
#   8,
#   550,
#   2101,
#   1307,
#   80,
#   2102,
#   2103,
#   989,
#   649,
#   2104,
#   210,
#   458,
#   990,
#   2105,
#   6,
#   22,
#   2106,
#   989,
#   2107,
#   89,
#   210,
#   243,
#   2108,
#   620,
#   1485,
#   237,
#   447,
#   20,
#   1141,
#   350,
#   5],
#  [243, 16, 459, 1, 276, 56, 6],
#  [187, 1],
#  [9, 2, 225, 1044, 1133, 1, 4, 307],
#  [5, 112],
#  [],
#  [484, 384, 222, 31, 562, 112],
#  [15, 2109, 255, 4, 3, 127, 1486, 2110],
#  [21, 4, 65, 2111, 431, 16],
#  [],
#  [4,
#   164,
#   461,
#   1487,
#   1488,
#   1108,
#   643,
#   225,
#   371,
#   46,
#   80,
#   2,
#   84,
#   11,
#   108,
#   523,
#   257],
#  [65, 377, 19, 2112, 479, 103],
#  [321,
#   78,
#   208,
#   739,
#   61,
#   716,
#   70,
#   264,
#   1489,
#   169,
#   172,
#   1142,
#   249,
#   158,
#   2,
#   13,
#   6,
#   118,
#   2113,
#   442,
#   104,
#   6,
#   363,
#   2114,
#   2115,
#   313,
#   31,
#   2116,
#   4,
#   382,
#   66,
#   92,
#   1035,
#   2117,
#   2118,
#   2119,
#   2120,
#   118,
#   357,
#   195,
#   72,
#   539,
#   25,
#   2121,
#   207,
#   179,
#   2122,
#   443,
#   2123],
#  [78, 7, 70, 2, 69, 344, 126, 117, 6, 154, 108, 3, 41],
#  [3, 9, 52],
#  [1, 4, 49, 261, 108, 112],
#  [1],
#  [8, 34],
#  [2, 48, 1490, 2124, 697, 203],
#  [],
#  [3, 1491, 4, 569, 162, 504],
#  [81],
#  [11, 14],
#  [9,
#   37,
#   101,
#   308,
#   303,
#   457,
#   354,
#   705,
#   795,
#   79,
#   4,
#   55,
#   216,
#   39,
#   27,
#   1492,
#   698,
#   4,
#   55,
#   99,
#   39,
#   27,
#   31,
#   161,
#   2125,
#   121,
#   1306,
#   2126,
#   21,
#   633,
#   4,
#   1018,
#   1143,
#   330,
#   2127],
#  [38, 1, 4, 269],
#  [211, 90, 4, 18, 130, 8, 259, 41, 87, 171, 22],
# ...
#  [65,
#   1534,
#   393,
#   34,
#   2,
#   26,
#   305,
#   814,
#   234,
#   239,
#   1535,
#   90,
#   124,
#   211,
#   278,
#   134,
#   73,
#   515,
#   290,
#   2,
#   71],
#  [480,
#   1,
#   2,
#   1139,
#   123,
#   64,
#   933,
#   639,
#   117,
#   6,
#   15,
#   115,
#   1536,
#   137,
#   40,
#   140,
#   26,
#   50,
#   2,
#   40,
#   276,
#   99],
#  [139],
#  [1, 116, 16, 9],
#  [2189, 186, 2, 13, 730, 37, 9, 36, 732, 88, 1512, 942],
#  [5, 3, 1, 193, 22, 6, 425, 10],
#  [640, 6, 86, 98, 15, 35, 805],
#  [17, 988, 573, 151, 63, 4, 96, 543, 66, 169, 158, 411, 169, 101, 173, 1142],
#  [379, 1161, 38, 1162, 407, 300, 205, 1161],
#  [918, 482, 182, 99],
#  [90, 4, 724, 10, 41, 1233, 1234],
#  [66, 337, 327, 5, 41, 358, 1537],
#  [146],
#  [37, 196, 433, 2, 12, 439, 499, 5, 3, 109],
#  [],
#  [243, 128, 39, 26, 476, 5, 212],
#  [26,
#   8,
#   5,
#   37,
#   915,
#   236,
#   344,
#   2190,
#   54,
#   15,
#   745,
#   52,
#   361,
#   16,
#   42,
#   37,
#   2191,
#   39,
#   804,
#   75,
#   418],
#  [640, 6, 86, 98, 15, 35, 805],
#  [654, 426, 11, 14, 143, 20, 2, 13, 741, 109, 4, 656, 2192, 3, 342],
#  [40, 305, 550],
#  [11, 14],
#  [179, 16, 17, 615, 22, 6, 511, 522, 206, 522, 521, 519],
#  [161,
#   46,
#   19,
#   5,
#   1538,
#   244,
#   631,
#   297,
#   616,
#   1065,
#   176,
#   383,
#   631,
#   8,
#   38,
#   1539,
#   1540,
#   114,
#   570,
#   616,
#   836,
#   5],
#  [3, 9, 65, 15],
#  [3, 9],
#  [1, 299, 7, 671, 2, 71, 1541],
#  [600, 111, 699, 2193, 338, 193, 2194, 79, 45, 41, 480, 83],
#  [146, 97, 16],
#  [218],
#  [582, 7, 21, 5, 8, 54],
#  [5, 8, 953],
#  [7,
#   2,
#   13,
#   356,
#   170,
#   89,
#   23,
#   7,
#   707,
#   85,
#   672,
#   31,
#   124,
#   931,
#   507,
#   6,
#   119,
#   15,
#   5,
#   3,
#   42],
#  [8, 17, 471, 15, 497, 36, 109],
#  [16],
#  [218, 92, 461, 1],
#  [1, 307],
#  [146,
#   11,
#   228,
#   2195,
#   7,
#   480,
#   83,
#   83,
#   38,
#   102,
#   2196,
#   174,
#   2197,
#   1448,
#   270,
#   384],
#  [1, 2, 363, 617, 15, 36, 1542, 60, 102, 164, 44, 28, 29],
#  [90,
#   341,
#   2,
#   164,
#   90,
#   217,
#   147,
#   37,
#   93,
#   341,
#   28,
#   29,
#   41,
#   134,
#   179,
#   901,
#   15,
#   1085,
#   2198,
#   9,
#   6],
#  [40, 110, 87, 2199, 196, 1163, 7, 167, 406, 738, 2200, 19, 169, 101, 173],
#  [2201, 90, 2202, 97, 16, 41, 249, 55, 180],
#  [399],
#  [130,
#   8,
#   17,
#   65,
#   62,
#   12,
#   128,
#   39,
#   251,
#   531,
#   229,
#   4,
#   2203,
#   283,
#   944,
#   1543,
#   18,
#   17,
#   815,
#   267,
#   232,
#   53,
#   240],
#  [95, 73, 202],
#  [1544, 786],
#  [7,
#   640,
#   22,
#   6,
#   5,
#   954,
#   24,
#   78,
#   69,
#   91,
#   18,
#   20,
#   493,
#   356,
#   949,
#   164,
#   44,
#   400,
#   138],
#  [46, 315, 20, 803, 12, 2204, 97, 3, 429, 3, 1],
#  [116, 1392, 58, 696],
#  [156,
#   7,
#   405,
#   57,
#   314,
#   22,
#   6,
#   512,
#   2205,
#   1164,
#   1518,
#   18,
#   131,
#   325,
#   659,
#   57,
#   368,
#   20,
#   19,
#   12,
#   175],
#  [93, 251, 1, 83, 1, 236],
#  [1, 22, 37, 20, 28, 91, 2206, 653, 1109],
#  [10, 107],
#  [2207,
#   139,
#   1513,
#   251,
#   521,
#   33,
#   321,
#   780,
#   25,
#   2208,
#   478,
#   333,
#   7,
#   190,
#   2209,
#   179,
#   8,
#   501,
#   12],
#  [5, 3, 170, 34, 12],
#  [879,
#   390,
#   9,
#   36,
#   2,
#   196,
#   433,
#   1049,
#   387,
#   503,
#   1318,
#   127,
#   653,
#   85,
#   23,
#   145,
#   1050,
#   1319,
#   23,
#   30,
#   23,
#   77,
#   649,
#   1051,
#   1320,
#   40,
#   370,
#   73,
#   3,
#   1052,
#   263,
#   296,
#   63,
#   22,
#   104,
#   142,
#   382,
#   766,
#   880,
#   146,
#   12,
#   25,
#   3,
#   129,
#   144,
#   165,
#   168,
#   7,
#   62,
#   588,
#   6,
#   85,
#   130,
#   20,
#   28,
#   736,
#   260,
#   1321,
#   221,
#   375,
#   1322,
#   45,
#   600,
#   2,
#   1323,
#   54,
#   2,
#   162,
#   504,
#   293,
#   21,
#   63,
#   68,
#   291,
#   68,
#   351,
#   164,
#   20,
#   28,
#   1053,
#   172,
#   505,
#   376],
#  [1, 1, 1, 1, 253, 8, 201, 264, 68, 47],
#  [3],
#  [41, 16, 305, 814, 24, 184, 278, 11, 14, 41, 11, 7, 87, 294, 7, 22, 40],
#  [3, 17, 239, 103, 403, 1545, 259, 19, 142, 64, 208],
#  [40, 22],
#  [1546,
#   20,
#   10,
#   156,
#   511,
#   61,
#   324,
#   25,
#   533,
#   297,
#   324,
#   160,
#   7,
#   590,
#   350,
#   46,
#   138,
#   614,
#   445,
#   555,
#   1547,
#   1165,
#   2,
#   1548,
#   1549,
#   80,
#   220,
#   61,
#   14,
#   373,
#   1550,
#   359],
#  [38,
#   71,
#   146,
#   523,
#   230,
#   298,
#   1551,
#   816,
#   25,
#   367,
#   2210,
#   2211,
#   445,
#   1166,
#   2212,
#   306,
#   25,
#   121,
#   523,
#   248,
#   890,
#   248,
#   80,
#   338,
#   2213,
#   1092,
#   277,
#   446,
#   204,
#   204,
#   100,
#   187,
#   338,
#   2214,
#   361,
#   2215,
#   213,
#   445,
#   446,
#   556,
#   26,
#   20,
#   101,
#   816,
#   227,
#   215,
#   28,
#   545,
#   106,
#   2216,
#   45,
#   19,
#   2217],
#  [107, 17, 558, 128, 39, 56, 14, 622, 32, 178, 10],
#  [1, 3, 499, 88, 132, 1167, 88, 1168, 280, 1552, 1553],
#  [10, 107],
#  [1484,
#   2218,
#   465,
#   2,
#   253,
#   8,
#   2219,
#   78,
#   144,
#   524,
#   29,
#   520,
#   10,
#   2220,
#   132,
#   59,
#   7,
#   1543,
#   145,
#   24,
#   1169],
#  [109, 160, 32],
#  [11, 500, 98, 534, 240],
#  [98, 140],
#  [2221, 20, 28, 25, 92, 46, 123, 52, 763, 28, 6],
#  [98, 13, 46, 94, 149, 141, 17, 24, 147, 734],
#  [14, 22, 23, 1554, 206, 1555, 70, 59, 1170, 551, 154, 26, 182, 6],
#  [385,
#   186,
#   2,
#   1556,
#   955,
#   681,
#   464,
#   125,
#   235,
#   288,
#   289,
#   196,
#   191,
#   235,
#   1557,
#   1558,
#   37,
#   8,
#   7,
#   956,
#   957,
#   1171,
#   397,
#   702,
#   896,
#   1559,
#   737,
#   9,
#   179,
#   5,
#   24,
#   169,
#   8],
#  [93, 129],
#  [5, 3],
#  [11, 14, 5, 81],
#  [883, 778, 2222, 2223],
#  [5, 8, 953],
#  [17,
#   1063,
#   2224,
#   556,
#   2225,
#   2,
#   10,
#   221,
#   8,
#   13,
#   25,
#   58,
#   20,
#   25,
#   952,
#   180,
#   127,
#   69,
#   503,
#   1560,
#   2226,
#   958,
#   2227],
#  [1, 261, 183, 1, 300, 4, 19, 59, 908, 132, 120],
#  [1, 57, 68, 14, 43, 2228, 289],
#  [41, 1, 108, 78, 18, 14, 1, 540, 126, 82],
#  [4, 239, 2229, 24, 53, 89, 995, 18, 2230, 650],
#  [107, 422, 4],
#  [307, 284, 2231],
#  [5, 3, 38, 1138, 8, 450, 56],
#  [8, 47, 6, 915, 236, 59],
#  [40, 41, 24, 53, 5],
#  [5, 3],
#  [1, 65, 13, 66, 186, 762, 4, 13, 315, 13, 240],
#  [1,
#   832,
#   193,
#   52,
#   244,
#   88,
#   6,
#   283,
#   153,
#   75,
#   20,
#   902,
#   806,
#   1561,
#   12,
#   789,
#   115,
#   2232,
#   44,
#   12,
#   285,
#   2233,
#   515,
#   42,
#   111,
#   12,
#   536,
#   39],
#  [124,
#   248,
#   14,
#   1562,
#   61,
#   44,
#   69,
#   206,
#   84,
#   177,
#   1516,
#   27,
#   74,
#   290,
#   2234,
#   27,
#   168,
#   11],
#  [434, 248, 399, 11, 228, 1563],
#  [97, 5, 81, 369, 44, 16, 191],
#  [3, 9, 36, 3, 49, 3, 17, 1564, 39, 6, 133],
#  [14,
#   29,
#   24,
#   290,
#   30,
#   23,
#   10,
#   15,
#   3,
#   118,
#   6,
#   8,
#   137,
#   1565,
#   113,
#   486,
#   1073,
#   97],
#  [1, 17, 58, 11, 220, 33, 799],
#  [778,
#   1104,
#   2235,
#   2236,
#   701,
#   2237,
#   701,
#   2238,
#   719,
#   2239,
#   1172,
#   85,
#   887,
#   905,
#   2240,
#   2241,
#   719,
#   701,
#   2242,
#   1007,
#   4,
#   2243,
#   2244,
#   2245,
#   2246],
#  [24,
#   42,
#   668,
#   224,
#   677,
#   35,
#   42,
#   568,
#   600,
#   197,
#   509,
#   169,
#   42,
#   153,
#   105,
#   166,
#   367,
#   4,
#   63,
#   31,
#   51,
#   220,
#   1142,
#   2247,
#   91,
#   651,
#   35,
#   271,
#   122,
#   174,
#   35,
#   31,
#   51,
#   330,
#   397,
#   612,
#   4,
#   2,
#   72,
#   2248,
#   239,
#   362,
#   648,
#   219,
#   2249,
#   284,
#   637,
#   1145,
#   23,
#   841,
#   2250,
#   17,
#   16,
#   9,
#   36,
#   42,
#   668,
#   224],
#  [16,
#   567,
#   24,
#   1537,
#   3,
#   118,
#   6,
#   139,
#   43,
#   765,
#   791,
#   357,
#   33,
#   17,
#   935,
#   301,
#   28,
#   29,
#   1173,
#   29,
#   93,
#   115,
#   207,
#   503,
#   24,
#   595,
#   19,
#   151,
#   175],
#  [5, 9, 3, 56, 944, 941, 113, 486, 122, 379, 39, 87, 430, 24, 959],
#  [1, 2, 13],
#  [8, 2251, 192, 170, 2252, 755, 7, 4, 58],
#  [594, 1, 187, 47, 83, 3],
#  [24,
#   53,
#   7,
#   18,
#   130,
#   30,
#   889,
#   298,
#   808,
#   319,
#   2253,
#   19,
#   12,
#   8,
#   89,
#   85,
#   1566,
#   27,
#   530,
#   163],
#  [1],
#  [1, 452],
#  [320, 11, 14, 11, 7, 87, 82, 145, 360],
#  [480,
#   83,
#   2254,
#   10,
#   161,
#   2255,
#   2256,
#   209,
#   196,
#   2257,
#   6,
#   100,
#   266,
#   2258,
#   1436,
#   960,
#   469,
#   183,
#   166,
#   328,
#   2259,
#   2260,
#   1567],
#  [1079, 8, 15, 63, 4],
#  [2261,
#   20,
#   73,
#   162,
#   196,
#   20,
#   433,
#   1,
#   326,
#   588,
#   571,
#   6,
#   28,
#   52,
#   45,
#   60,
#   802,
#   236,
#   6,
#   142,
#   20,
#   82,
#   333,
#   7,
#   50,
#   168,
#   73,
#   200,
#   485],
#  [1],
#  [5, 911],
#  [41, 16],
#  [1],
#  [81, 618, 1, 2],
#  [98, 125, 815, 114, 416],
#  [5, 37, 207, 15, 36, 372, 155, 264, 15],
#  [1],
#  [44,
#   2,
#   56,
#   160,
#   388,
#   2,
#   2,
#   13,
#   11,
#   14,
#   9,
#   1174,
#   2262,
#   25,
#   624,
#   111,
#   388,
#   2,
#   2263,
#   648,
#   9],
#  [44, 177, 150, 86, 561, 9, 901, 1097, 26, 75, 281, 303, 196, 697, 225],
#  [11,
#   14,
#   157,
#   50,
#   560,
#   2264,
#   580,
#   1450,
#   2265,
#   1544,
#   120,
#   78,
#   2266,
#   290,
#   711,
#   1175],
#  [159, 2, 206, 143, 17, 5, 8, 34],
#  [8],
#  [44, 608, 680, 29, 1568],
#  [1, 9, 36, 150, 256, 9],
#  [40, 7, 50, 203, 238, 817],
#  [15, 9, 26, 16],
#  [187,
#   1,
#   7,
#   47,
#   68,
#   244,
#   2267,
#   251,
#   161,
#   63,
#   192,
#   1569,
#   98,
#   38,
#   191,
#   1176,
#   337,
#   12,
#   5,
#   39,
#   1570],
#  [2268, 110, 379, 1161],
#  [24, 1177, 1571, 41, 188, 30, 23, 49, 660],
#  [15, 46, 35, 1363],
#  [8, 546, 2269, 13, 9, 65, 467],
#  [5, 37],
#  [],
#  [44, 687, 12, 1],
#  [187,
#   1,
#   250,
#   491,
#   44,
#   564,
#   806,
#   100,
#   1572,
#   216,
#   39,
#   320,
#   11,
#   14,
#   605,
#   98,
#   282,
#   217,
#   180,
#   958,
#   598,
#   2270,
#   352,
#   60,
#   2271,
#   267,
#   232,
#   413,
#   579,
#   219,
#   170,
#   57,
#   368,
#   8,
#   571,
#   464,
#   2272,
#   248,
#   257,
#   31,
#   8,
#   75,
#   2273,
#   2274,
#   2275,
#   43,
#   77,
#   26,
#   317,
#   2276,
#   2277,
#   544,
#   199,
#   128,
#   961],
#  [1, 24, 53, 240, 87, 40],
#  [315, 2, 225, 58, 4, 360, 6, 59, 132, 295, 87, 775],
#  [2,
#   13,
#   225,
#   30,
#   15,
#   2278,
#   137,
#   249,
#   2279,
#   16,
#   9,
#   31,
#   1573,
#   94,
#   436,
#   15,
#   955,
#   2280,
#   9,
#   31,
#   8,
#   137,
#   2281,
#   124,
#   87,
#   706,
#   5,
#   3,
#   4,
#   82,
#   31,
#   92,
#   137,
#   3,
#   1242,
#   2282,
#   280,
#   2283,
#   39,
#   116,
#   506,
#   2284],
#  [1503,
#   9,
#   1504,
#   167,
#   23,
#   477,
#   9,
#   312,
#   31,
#   42,
#   28,
#   116,
#   560,
#   6,
#   42,
#   28,
#   6,
#   22,
#   47,
#   31,
#   19,
#   102,
#   42,
#   28,
#   99,
#   6,
#   22,
#   6,
#   92,
#   1505,
#   42,
#   99,
#   449,
#   7,
#   265,
#   10],
#  [484,
#   35,
#   57,
#   368,
#   50,
#   43,
#   57,
#   771,
#   336,
#   1566,
#   644,
#   33,
#   163,
#   2285,
#   336,
#   5,
#   37,
#   180,
#   1040,
#   10,
#   745,
#   362],
#  [1],
#  [1574,
#   778,
#   1575,
#   1576,
#   962,
#   1577,
#   1578,
#   962,
#   198,
#   1579,
#   1580,
#   719,
#   1581,
#   1582,
#   1583,
#   1584,
#   1172,
#   1585,
#   1586,
#   1587,
#   719,
#   1588,
#   1589,
#   887,
#   1590,
#   1591,
#   1592,
#   1593,
#   1594,
#   198],
#  [16, 17],
#  [116, 10, 183, 8, 63, 96, 376, 491, 2286],
#  [79, 4, 757, 490, 101, 167, 23, 33, 1595, 780, 229],
#  [112,
#   71,
#   790,
#   12,
#   1596,
#   2287,
#   272,
#   55,
#   2288,
#   43,
#   194,
#   115,
#   33,
#   300,
#   18,
#   1286,
#   62,
#   90,
#   1020,
#   474,
#   2289,
#   148,
#   8,
#   557,
#   1597,
#   963,
#   43,
#   368,
#   1178,
#   2290,
#   526,
#   1179,
#   76,
#   301,
#   922,
#   478,
#   920,
#   139,
#   641,
#   301,
#   21,
#   45,
#   26,
#   131,
#   963,
#   1178,
#   2291,
#   925,
#   963,
#   1178,
#   594,
#   1180,
#   1598,
#   242,
#   421,
#   20,
#   46,
#   246,
#   412,
#   480,
#   441,
#   1179,
#   76,
#   55,
#   43,
#   1180,
#   451,
#   50,
#   139,
#   750,
#   1123,
#   1179,
#   76,
#   1598,
#   43,
#   641,
#   55,
#   57,
#   202,
#   24,
#   290,
#   139,
#   538,
#   114,
#   1599,
#   254,
#   720,
#   17,
#   599,
#   2292,
#   20,
#   334,
#   162],
#  [33, 40, 4, 1, 51, 88, 6, 603, 39, 639, 192, 233],
#  [5, 8, 1600],
#  [5, 112, 156, 86, 755],
#  [1, 71],
#  [636, 245, 77, 79, 1068, 30, 10, 205, 56, 50, 2, 48, 12, 95, 73, 162],
#  [5, 3, 2293, 15, 214, 268, 1],
#  [161, 106, 322, 7, 1181, 211, 19, 16, 8, 34, 231, 1424, 75, 69],
#  [38,
#   202,
#   155,
#   1162,
#   1,
#   121,
#   99,
#   545,
#   77,
#   22,
#   236,
#   45,
#   123,
#   52,
#   1,
#   469,
#   21,
#   75,
#   203,
#   253,
#   792,
#   2294,
#   46,
#   121,
#   4,
#   138],
#  [303, 1, 79, 756, 254, 181, 250, 514, 4, 1493, 1494, 277],
#  [376, 602, 33, 33, 1182, 342, 61],
#  [638,
#   528,
#   950,
#   346,
#   818,
#   2295,
#   20,
#   1474,
#   2296,
#   935,
#   130,
#   116,
#   590,
#   1148,
#   207,
#   1527,
#   2297,
#   20,
#   2,
#   23,
#   622,
#   38,
#   2,
#   48,
#   1157,
#   67,
#   389,
#   2298,
#   1183,
#   27,
#   667,
#   77,
#   85,
#   2299,
#   45,
#   5,
#   2300,
#   427,
#   274,
#   46,
#   207,
#   17,
#   1601,
#   2301,
#   2302,
#   2303,
#   362,
#   151,
#   602,
#   108,
#   17,
#   42,
#   97,
#   1184],
#  [58, 47, 108, 112, 171, 79],
#  [819, 485],
#  [110,
#   161,
#   147,
#   444,
#   1602,
#   752,
#   356,
#   29,
#   184,
#   19,
#   108,
#   492,
#   412,
#   20,
#   18,
#   2304,
#   161,
#   272,
#   111,
#   143,
#   10],
#  [5, 3],
#  [26, 8, 2, 13, 83, 51, 14, 43, 154, 201, 2, 13],
#  [395, 36, 9, 2, 148, 932, 459, 477, 339, 136, 7, 392, 6, 310],
#  [1, 251, 888, 742, 4, 889],
#  [11,
#   14,
#   7,
#   820,
#   290,
#   10,
#   1176,
#   50,
#   56,
#   30,
#   23,
#   4,
#   53,
#   34,
#   110,
#   517,
#   162,
#   73,
#   41,
#   370,
#   577],
#  [5, 3],
#  [35,
#   341,
#   128,
#   89,
#   471,
#   12,
#   26,
#   464,
#   235,
#   288,
#   125,
#   85,
#   964,
#   238,
#   1185,
#   288,
#   1069,
#   80,
#   97,
#   289,
#   101,
#   12,
#   1004,
#   21,
#   31,
#   98,
#   387,
#   239,
#   35,
#   3,
#   10,
#   134],
#  [5, 115, 37],
#  [],
#  [1, 34, 2, 13, 153, 537, 7, 22, 6, 163, 19, 420, 259],
#  [11, 7, 33, 964, 267, 47, 456, 61],
#  [107, 10, 98, 38, 12, 1186, 610],
#  [466,
#   186,
#   2,
#   28,
#   29,
#   41,
#   1,
#   130,
#   211,
#   89,
#   100,
#   1603,
#   2305,
#   2306,
#   2307,
#   1604,
#   2308,
#   821,
#   18,
#   534,
#   1605,
#   2309,
#   282,
#   69,
#   283],
#  [2310, 261, 128, 21, 263, 208, 417, 523, 208, 211, 965, 591, 5, 112, 553],
#  [912,
#   188,
#   1606,
#   1,
#   231,
#   966,
#   345,
#   480,
#   628,
#   966,
#   559,
#   568,
#   1184,
#   241,
#   117,
#   6,
#   1187,
#   319,
#   3,
#   139,
#   252,
#   33],
#  [1, 1],
#  [211,
#   21,
#   20,
#   28,
#   99,
#   91,
#   202,
#   34,
#   4,
#   669,
#   135,
#   73,
#   4,
#   48,
#   67,
#   438,
#   1282,
#   226,
#   27,
#   74,
#   25,
#   3,
#   292,
#   4,
#   87,
#   16,
#   18,
#   174,
#   8,
#   43,
#   194,
#   2311,
#   319,
#   118,
#   6,
#   79,
#   45,
#   670,
#   310,
#   16,
#   284,
#   258,
#   16,
#   9,
#   459,
#   891,
#   54,
#   67,
#   438,
#   42,
#   200,
#   233,
#   605,
#   10,
#   37,
#   210,
#   281,
#   17,
#   10,
#   306,
#   193,
#   217,
#   226,
#   27,
#   74,
#   5,
#   2312,
#   74,
#   74,
#   815,
#   33,
#   226,
#   82,
#   226,
#   82,
#   519,
#   4,
#   67,
#   489,
#   1607,
#   19,
#   348,
#   489,
#   14,
#   74,
#   2313,
#   21,
#   27,
#   221,
#   14,
#   502,
#   2314,
#   120,
#   259,
#   447,
#   198,
#   61,
#   758,
#   221,
#   23,
#   126,
#   100,
#   240,
#   80,
#   489,
#   207,
#   101,
#   193,
#   544,
#   253,
#   2315,
#   20,
#   438,
#   226,
#   74,
#   80,
#   2316,
#   634,
#   2317,
#   16,
#   822,
#   89,
#   19,
#   226,
#   489,
#   166,
#   2,
#   48,
#   2318,
#   27,
#   74],
#  [307, 118, 6, 139, 43, 201, 1608],
#  [95, 181, 17, 85, 366, 27, 56, 200, 454],
#  [250,
#   938,
#   202,
#   54,
#   261,
#   58,
#   675,
#   26,
#   8,
#   403,
#   294,
#   170,
#   875,
#   578,
#   8,
#   2319,
#   2320,
#   120,
#   245,
#   220,
#   270,
#   310,
#   261,
#   19,
#   35,
#   378,
#   100,
#   658,
#   32,
#   62,
#   75,
#   947,
#   21,
#   355,
#   403,
#   294,
#   14,
#   16,
#   18,
#   84,
#   2321,
#   2322],
#  [63, 22, 967, 189, 340, 166, 229, 62, 159, 968, 313, 967, 684, 968, 1609],
#  [11, 84],
#  [26, 5, 2323, 50, 521, 8],
#  [2, 5, 37, 51, 511, 20, 6, 10],
#  [365, 22, 171, 19],
#  [183, 1, 4, 140, 83, 25, 8, 75, 19, 65, 1188, 685, 458, 96],
#  [505, 308, 168, 18, 8, 260, 470, 18, 8, 197, 169, 47, 63, 24, 58, 7],
#  [244],
#  [312, 10, 66, 143, 704, 1610, 201, 704, 292, 201, 300, 1305, 320, 2324],
#  [1, 2],
#  [95, 181, 1114, 784, 304, 299, 726, 101, 34, 185, 7, 37, 37, 259],
#  [160, 4, 20, 101, 585, 46, 796, 78, 2, 31, 95, 18, 334, 7, 926, 56, 46, 517],
#  [],
#  [255, 135, 114],
#  [],
#  [44, 2325, 129, 775, 49, 190, 219, 118, 6, 3, 127],
#  [33, 478, 7, 938],
#  [147, 386, 109, 15, 3, 9, 81, 1611],
#  [],
#  [1, 320, 11, 7, 1612, 289, 379, 124, 153, 80, 965],
#  [1, 2, 71],
#  [1, 4, 1, 2, 13, 321, 15, 70, 450],
#  [1, 2, 32, 86, 241, 6, 799, 773, 9],
#  [3, 17, 3, 72],
#  [24, 53],
#  [300, 21, 104, 454, 10],
#  [8,
#   314,
#   265,
#   170,
#   18,
#   8,
#   903,
#   126,
#   14,
#   43,
#   22,
#   104,
#   92,
#   33,
#   98,
#   9,
#   46,
#   2326,
#   416],
#  [8, 34],
#  [3],
#  [4, 83, 3, 15],
#  [1,
#   2,
#   32,
#   4,
#   83,
#   32,
#   336,
#   381,
#   710,
#   120,
#   15,
#   83,
#   2327,
#   39,
#   38,
#   28,
#   29,
#   44,
#   3,
#   191,
#   199],
#  [1, 2, 32],
#  [5, 16],
#  [691, 16, 2328, 9, 18, 92, 503, 969, 12, 178, 2, 10, 935],
#  [355,
#   772,
#   945,
#   143,
#   150,
#   97,
#   326,
#   34,
#   2329,
#   898,
#   257,
#   14,
#   1613,
#   119,
#   15,
#   1145,
#   4,
#   82,
#   664,
#   2330,
#   117,
#   178,
#   721,
#   459,
#   119,
#   84,
#   46,
#   517,
#   1009,
#   394,
#   63,
#   4,
#   22,
#   6,
#   2331,
#   1614,
#   2332,
#   1189,
#   1062,
#   114,
#   139,
#   713,
#   119,
#   2333,
#   340,
#   82,
#   50,
#   18,
#   1613,
#   859,
#   2334,
#   153,
#   444,
#   959,
#   304,
#   112,
#   528,
#   349,
#   199,
#   128,
#   961],
#  [3, 17, 347, 152, 78, 352, 100, 936, 33, 35, 832],
#  [8, 269],
#  [207,
#   2335,
#   675,
#   2336,
#   44,
#   259,
#   2337,
#   1483,
#   908,
#   2338,
#   2339,
#   417,
#   2340,
#   132,
#   59,
#   31,
#   2341,
#   2342,
#   2343,
#   29,
#   520,
#   20,
#   29,
#   822,
#   501],
#  [508, 17, 187, 1],
#  [114,
#   2344,
#   424,
#   1158,
#   352,
#   172,
#   2345,
#   95,
#   334,
#   70,
#   720,
#   1615,
#   160,
#   752,
#   2346,
#   2347,
#   172,
#   352],
#  [16, 197, 122, 37],
#  [107, 98, 576, 12, 577],
#  [315, 149, 141],
#  [1, 9, 36, 150, 256, 9],
#  [2, 3, 479, 45, 127, 410],
#  ...]

# %%
seqmattrain = sequence.pad_sequences(seqtrain, maxlen= int(max_len)) #step2
seqmattrain
# Out:
# array([[   0,    0,    0, ...,    8, 1231,  983],
#        [   0,    0,    0, ...,    4,   92, 1232],
#        [   0,    0,    0, ...,  203,  238,  278],
#        ...,
#        [   0,    0,    0, ...,  191,    3,   17],
#        [   0,    0,    0, ...,    0,    0,  385],
#        [   0,    0,    0, ...,    1,    2,   71]], dtype=int32)

# %%
seqtest = tok.texts_to_sequences(xtest)
seqmattest = sequence.pad_sequences(seqtest, maxlen=int(max_len))

# %%
vocab_len
# Out:
# 2945

# %%
rnn = Sequential()

rnn.add(Embedding(vocab_len+1,700, input_length=int(max_len), mask_zero=True))
rnn.add(SimpleRNN(units=32, activation="tanh"))
rnn.add(Dense(units=32, activation="relu"))
rnn.add(Dropout(0.2))

rnn.add(Dense(units=1, activation="sigmoid"))

rnn.compile(optimizer="adam", loss="binary_crossentropy")

rnn.fit(seqmattrain, ytrain, batch_size=50, epochs=50)

ypred = rnn.predict(seqmattest)

ypred = ypred>0.5
# Out:
# Epoch 1/50
# 45/45 [==============================] - 5s 60ms/step - loss: 0.3915
# Epoch 2/50
# 45/45 [==============================] - 3s 68ms/step - loss: 0.1441
# Epoch 3/50
# 45/45 [==============================] - 4s 98ms/step - loss: 0.0518
# Epoch 4/50
# 45/45 [==============================] - 3s 69ms/step - loss: 0.0292
# Epoch 5/50
# 45/45 [==============================] - 3s 64ms/step - loss: 0.0248
# Epoch 6/50
# 45/45 [==============================] - 3s 66ms/step - loss: 0.0234
# Epoch 7/50
# 45/45 [==============================] - 4s 79ms/step - loss: 0.0228
# Epoch 8/50
# 45/45 [==============================] - 3s 65ms/step - loss: 0.0226
# Epoch 9/50
# 45/45 [==============================] - 3s 59ms/step - loss: 0.0221
# Epoch 10/50
# 45/45 [==============================] - 3s 64ms/step - loss: 0.0217
# Epoch 11/50
# 45/45 [==============================] - 3s 77ms/step - loss: 0.0213
# Epoch 12/50
# 45/45 [==============================] - 3s 73ms/step - loss: 0.0211
# Epoch 13/50
# 45/45 [==============================] - 3s 76ms/step - loss: 0.0210
# Epoch 14/50
# 45/45 [==============================] - 3s 62ms/step - loss: 0.0208
# Epoch 15/50
# 45/45 [==============================] - 3s 68ms/step - loss: 0.0207
# Epoch 16/50
# 45/45 [==============================] - 3s 72ms/step - loss: 0.0207
# Epoch 17/50
# 45/45 [==============================] - 3s 59ms/step - loss: 0.0205
# Epoch 18/50
# 45/45 [==============================] - 3s 57ms/step - loss: 0.0207
# Epoch 19/50
# 45/45 [==============================] - 3s 59ms/step - loss: 0.0200
# Epoch 20/50
# 45/45 [==============================] - 4s 93ms/step - loss: 0.0205
# Epoch 21/50
# 45/45 [==============================] - 3s 62ms/step - loss: 0.0205
# Epoch 22/50
# 45/45 [==============================] - 3s 72ms/step - loss: 0.0202
# Epoch 23/50
# 45/45 [==============================] - 3s 58ms/step - loss: 0.0202
# Epoch 24/50
# 45/45 [==============================] - 4s 88ms/step - loss: 0.0202
# Epoch 25/50
# 45/45 [==============================] - 3s 58ms/step - loss: 0.0201
# Epoch 26/50
# 45/45 [==============================] - 3s 58ms/step - loss: 0.0203
# Epoch 27/50
# 45/45 [==============================] - 3s 70ms/step - loss: 0.0203
# Epoch 28/50
# 45/45 [==============================] - 4s 83ms/step - loss: 0.0197
# Epoch 29/50
# 45/45 [==============================] - 3s 67ms/step - loss: 0.0198
# Epoch 30/50
# 45/45 [==============================] - 3s 62ms/step - loss: 0.0197
# Epoch 31/50
# 45/45 [==============================] - 3s 63ms/step - loss: 0.0200
# Epoch 32/50
# 45/45 [==============================] - 4s 93ms/step - loss: 0.0199
# Epoch 33/50
# 45/45 [==============================] - 3s 67ms/step - loss: 0.0201
# Epoch 34/50
# 45/45 [==============================] - 3s 69ms/step - loss: 0.0197
# Epoch 35/50
# 45/45 [==============================] - 3s 73ms/step - loss: 0.0199
# Epoch 36/50
# 45/45 [==============================] - 4s 90ms/step - loss: 0.0207
# Epoch 37/50
# 45/45 [==============================] - 3s 57ms/step - loss: 0.0202
# Epoch 38/50
# 45/45 [==============================] - 3s 68ms/step - loss: 0.0198
# Epoch 39/50
# 45/45 [==============================] - 3s 66ms/step - loss: 0.0201
# Epoch 40/50
# 45/45 [==============================] - 4s 100ms/step - loss: 0.0202
# Epoch 41/50
# 45/45 [==============================] - 3s 67ms/step - loss: 0.0201
# Epoch 42/50
# 45/45 [==============================] - 3s 64ms/step - loss: 0.0201
# Epoch 43/50
# 45/45 [==============================] - 3s 58ms/step - loss: 0.0203
# Epoch 44/50
# 45/45 [==============================] - 4s 90ms/step - loss: 0.0210
# Epoch 45/50
# 45/45 [==============================] - 3s 65ms/step - loss: 0.0200
# Epoch 46/50
# 45/45 [==============================] - 3s 63ms/step - loss: 0.0198
# Epoch 47/50
# 45/45 [==============================] - 3s 69ms/step - loss: 0.0205
# Epoch 48/50
# 45/45 [==============================] - 3s 72ms/step - loss: 0.0201
# Epoch 49/50
# 45/45 [==============================] - 3s 78ms/step - loss: 0.0204
# Epoch 50/50
# 45/45 [==============================] - 3s 59ms/step - loss: 0.0202
# 30/30 [==============================] - 0s 7ms/step

# %%
from sklearn.metrics import classification_report

print(classification_report(ytest,ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.37      0.48        73
#            1       0.95      0.99      0.97       872
#
#     accuracy                           0.94       945
#    macro avg       0.81      0.68      0.72       945
# weighted avg       0.93      0.94      0.93       945

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
df['clean_review']=le.fit_transform(df['clean_review'])

# %%
df.head()
# Out:
#    rating                                   verified_reviews  feedback  \
# 0       5                                      Love my Echo!         1
# 1       5                                          Loved it!         1
# 2       4  Sometimes while playing a game, you can answer...         1
# 3       5  I have had a lot of fun with this thing. My 4 ...         1
# 4       5                                              Music         1
#
#    clean_review  SentLen
# 0          1104        2
# 1          1360        1
# 2          1753       17
# 3          1027       18
# 4          1404        1

# %%
x=df['clean_review']
y=df['feedback']

# %%
#xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.3, random_state=1)

# %%
# xtrain
# Out:
# 1433    2132
# 2833    1806
# 1807    1089
# 1447       0
# 1328     776
#         ...
# 2763       0
# 905       10
# 1096     715
# 235      995
# 1061    1144
# Name: clean_review, Length: 2205, dtype: int64

# %%
from imblearn.over_sampling import SMOTE

# %%
sm=SMOTE(sampling_strategy='minority')
x_res,y_res=sm.fit_resample(x,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-e4818544e6e8> in <cell line: 2>()
#       1 sm=SMOTE(sampling_strategy='minority')
# ----> 2 x_res,y_res=sm.fit_resample(x,y)
#
# /usr/local/lib/python3.10/dist-packages/imblearn/base.py in fit_resample(self, X, y)
#     201         """
#     202         self._validate_params()
# --> 203         return super().fit_resample(X, y)
#     204
#     205     def _more_tags(self):
#
# /usr/local/lib/python3.10/dist-packages/imblearn/base.py in fit_resample(self, X, y)
#      80         check_classification_targets(y)
#      81         arrays_transformer = ArraysTransformer(X, y)
# ---> 82         X, y, binarize_y = self._check_X_y(X, y)
#      83
#      84         self.sampling_strategy_ = check_sampling_strategy(
#
# /usr/local/lib/python3.10/dist-packages/imblearn/base.py in _check_X_y(self, X, y, accept_sparse)
#     154             accept_sparse = ["csr", "csc"]
#     155         y, binarize_y = check_target_type(y, indicate_one_vs_all=True)
# --> 156         X, y = self._validate_data(X, y, reset=True, accept_sparse=accept_sparse)
#     157         return X, y, binarize_y
#     158
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     582                 y = check_array(y, input_name="y", **check_y_params)
#     583             else:
# --> 584                 X, y = check_X_y(X, y, **check_params)
#     585             out = X, y
#     586
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1104         )
#    1105
# -> 1106     X = check_array(
#    1107         X,
#    1108         accept_sparse=accept_sparse,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     900             # If input is 1D raise error
#     901             if array.ndim == 1:
# --> 902                 raise ValueError(
#     903                     "Expected 2D array, got 1D array instead:\narray={}.\n"
#     904                     "Reshape your data either using array.reshape(-1, 1) if "
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[1104 1360 1753 ... 1322  254  639].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
